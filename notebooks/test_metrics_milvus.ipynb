# %%
from datasets import load_dataset
import pandas as pd
from ir_eval.metrics import recall, precision, hole, ndcg
from sentence_transformers import SentenceTransformer, util, CrossEncoder
from ir_eval.utils_prompt import load_prompt_text, eval_prompt, preprocess_prompt
import collections
import os
import json
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load trec covid dataset
# https://paperswithcode.com/dataset/trec-covid

# %%
corpus = load_dataset("BeIR/trec-covid", 'corpus')['corpus']
queries = load_dataset("BeIR/trec-covid", 'queries')['queries']
qrels = load_dataset("BeIR/trec-covid-qrels")

# %%
queries
# Out:
# Dataset({
#     features: ['_id', 'title', 'text'],
#     num_rows: 50
# })

# %%
def combine_text(example):
    example['full_text'] = '[Title] ' + example['title'] + ' [TEXT] ' + example['text']
    return example
corpus = corpus.map(combine_text)

# %%
qid_2_query = dict(zip(queries['_id'], queries['text']))
docid_2_title = dict(zip(corpus['_id'], corpus['title']))
docid_2_text = dict(zip(corpus['_id'], corpus['text']))
docid_2_combined_text = dict(zip(corpus['_id'], [title + " " + text for title, text in zip(corpus['title'], corpus['text'])]))

# %% [markdown]
# ## Milvus BM25

# %%
# https://zilliz.com/blog/getting-started-with-a-milvus-connection
from milvus import default_server
default_server.start()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 3
#       1 # https://zilliz.com/blog/getting-started-with-a-milvus-connection
#       2 from milvus import default_server
# ----> 3 default_server.start()
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/milvus/__init__.py:400, in start(self)
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/milvus/__init__.py:162, in resolve(self)
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/milvus/__init__.py:284, in write_config(self)
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/shutil.py:431, in copy(src, dst, follow_symlinks)
#     429 if os.path.isdir(dst):
#     430     dst = os.path.join(dst, os.path.basename(src))
# --> 431 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     432 copymode(src, dst, follow_symlinks=follow_symlinks)
#     433 return dst
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/shutil.py:256, in copyfile(src, dst, follow_symlinks)
#     254     os.symlink(os.readlink(src), dst)
#     255 else:
# --> 256     with open(src, 'rb') as fsrc:
#     257         try:
#     258             with open(dst, 'wb') as fdst:
#     259                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/yangyutu/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/milvus/data/glog.conf'

# %%
from pymilvus import MilvusClient
client = MilvusClient("milvus_demo.db")

# %%
import milvus
milvus.__version__
# Out:
# '2.3.5'

# %%
from pymilvus import (
    connections,
    utility,
    FieldSchema,
    CollectionSchema,
    DataType,
    Collection,
)

# # Connect to Milvus server
# connections.connect(
#    host='127.0.0.1',
#    port=default_server.listen_port)

# %%
from pymilvus.model.sparse.bm25.tokenizers import build_default_analyzer
from pymilvus.model.sparse import BM25EmbeddingFunction

# %%
# analyzer  removes common stopwords in a particular language, tokenizes each remaining word, and then gathers the statistics of each token’s relevancy.
analyzer = build_default_analyzer(language="en")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/yangyutu/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Create corpus based on product title
corpus = list(docid_2_combined_text.values())

# Use the analyzer to instantiate the BM25EmbeddingFunction
bm25_ef = BM25EmbeddingFunction(analyzer)
# Fit the model on the corpus to get the statistics of the corpus
bm25_ef.fit(corpus)

# %%
corpus_bm25_embeddings = bm25_ef.encode_documents(corpus)

# %%
client = MilvusClient(uri="http://localhost:19530")

# %%
# Define collection name
collection_name = "trec_covid_bm25"

# Drop collection if it exists
if utility.has_collection(collection_name):
    utility.drop_collection(collection_name)

# Define fields for the collection

fields = [
    FieldSchema(name="pk", dtype=DataType.VARCHAR,
                is_primary=True, auto_id=True, max_length=100),
    FieldSchema(name="full_text", dtype=DataType.VARCHAR, max_length=2048),
    FieldSchema(name="full_text_vector", dtype=DataType.SPARSE_FLOAT_VECTOR),
]

# Create collection schema
schema = CollectionSchema(fields=fields, description="TREC-COVID BM25 collection")


# Create collection
#collection = client.create_collection(collection_name=collection_name, schema=schema)

collection = Collection(name=collection_name, schema=schema)

sparse_index = {"index_type": "SPARSE_INVERTED_INDEX", "metric_type": "IP"}
collection.create_index(field_name="full_text_vector", index_params=sparse_index)


# Insert data
entities = [
    corpus,  # text field
    corpus_bm25_embeddings,  # embedding field
]

collection.insert(entities)
collection.flush()
# Out:
# 2025-02-22 22:24:39,723 [ERROR][handler]: RPC error: [create_index], <MilvusException: (code=1100, message=create index on 104 field is not supported: invalid parameter[expected=supported field][actual=create index on 104 field])>, <Time:{'RPC start': '2025-02-22 22:24:39.719441', 'RPC error': '2025-02-22 22:24:39.722983'}> (decorators.py:140)
# ---------------------------------------------------------------------------
# MilvusException                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[29], line 27
#      26 sparse_index = {"index_type": "SPARSE_INVERTED_INDEX", "metric_type": "IP"}
# ---> 27 collection.create_index(field_name="full_text_vector", index_params=sparse_index)
#      30 # Insert data
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/orm/collection.py:1372, in Collection.create_index(self, field_name, index_params, timeout, **kwargs)
#    1371 conn = self._get_connection()
# -> 1372 return conn.create_index(self._name, field_name, index_params, timeout=timeout, **kwargs)
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/decorators.py:141, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     140     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 141     raise e from e
#     142 except grpc.FutureTimeoutError as e:
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/decorators.py:137, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     136     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 137     return func(*args, **kwargs)
#     138 except MilvusException as e:
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/decorators.py:176, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     175     self.set_onetime_request_id(req_id)
# --> 176 return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/decorators.py:116, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     115     else:
# --> 116         raise e from e
#     117 except Exception as e:
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/decorators.py:86, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      85 try:
# ---> 86     return func(*args, **kwargs)
#      87 except grpc.RpcError as e:
#      88     # Do not retry on these codes
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/client/grpc_handler.py:1023, in GrpcHandler.create_index(self, collection_name, field_name, params, timeout, **kwargs)
#    1022 status = future.result()
# -> 1023 check_status(status)
#    1025 if kwargs.get("sync", True):
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/client/utils.py:64, in check_status(status)
#      63 if status.code != 0 or status.error_code != 0:
# ---> 64     raise MilvusException(status.code, status.reason, status.error_code)
#
# MilvusException: <MilvusException: (code=1100, message=create index on 104 field is not supported: invalid parameter[expected=supported field][actual=create index on 104 field])>
#
# The above exception was the direct cause of the following exception:
#
# MilvusException                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[29], line 27
#      26 sparse_index = {"index_type": "SPARSE_INVERTED_INDEX", "metric_type": "IP"}
# ---> 27 collection.create_index(field_name="full_text_vector", index_params=sparse_index)
#      30 # Insert data
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/orm/collection.py:1372, in Collection.create_index(self, field_name, index_params, timeout, **kwargs)
#    1371 conn = self._get_connection()
# -> 1372 return conn.create_index(self._name, field_name, index_params, timeout=timeout, **kwargs)
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/decorators.py:141, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     140     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 141     raise e from e
#     142 except grpc.FutureTimeoutError as e:
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/decorators.py:137, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     136     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 137     return func(*args, **kwargs)
#     138 except MilvusException as e:
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/decorators.py:176, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     175     self.set_onetime_request_id(req_id)
# --> 176 return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/decorators.py:116, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     115     else:
# --> 116         raise e from e
#     117 except Exception as e:
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/decorators.py:86, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      85 try:
# ---> 86     return func(*args, **kwargs)
#      87 except grpc.RpcError as e:
#      88     # Do not retry on these codes
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/client/grpc_handler.py:1023, in GrpcHandler.create_index(self, collection_name, field_name, params, timeout, **kwargs)
#    1022 status = future.result()
# -> 1023 check_status(status)
#    1025 if kwargs.get("sync", True):
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/client/utils.py:64, in check_status(status)
#      63 if status.code != 0 or status.error_code != 0:
# ---> 64     raise MilvusException(status.code, status.reason, status.error_code)
#
# MilvusException: <MilvusException: (code=1100, message=create index on 104 field is not supported: invalid parameter[expected=supported field][actual=create index on 104 field])>
#
# The above exception was the direct cause of the following exception:
#
# MilvusException                           Traceback (most recent call last)
# Cell In[29], line 27
#      24 collection = Collection(name=collection_name, schema=schema)
#      26 sparse_index = {"index_type": "SPARSE_INVERTED_INDEX", "metric_type": "IP"}
# ---> 27 collection.create_index(field_name="full_text_vector", index_params=sparse_index)
#      30 # Insert data
#      31 entities = [
#      32     corpus,  # text field
#      33     corpus_bm25_embeddings,  # embedding field
#      34 ]
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/orm/collection.py:1372, in Collection.create_index(self, field_name, index_params, timeout, **kwargs)
#    1334 """Creates index for a specified field, with a index name.
#    1335
#    1336 Args:
#    (...)
#    1369     Status(code=0, message='')
#    1370 """
#    1371 conn = self._get_connection()
# -> 1372 return conn.create_index(self._name, field_name, index_params, timeout=timeout, **kwargs)
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/decorators.py:141, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     139     record_dict["RPC error"] = str(datetime.datetime.now())
#     140     LOGGER.error(f"RPC error: [{inner_name}], {e}, <Time:{record_dict}>")
# --> 141     raise e from e
#     142 except grpc.FutureTimeoutError as e:
#     143     record_dict["gRPC timeout"] = str(datetime.datetime.now())
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/decorators.py:137, in error_handler.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     135 try:
#     136     record_dict["RPC start"] = str(datetime.datetime.now())
# --> 137     return func(*args, **kwargs)
#     138 except MilvusException as e:
#     139     record_dict["RPC error"] = str(datetime.datetime.now())
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/decorators.py:176, in tracing_request.<locals>.wrapper.<locals>.handler(self, *args, **kwargs)
#     174 if req_id:
#     175     self.set_onetime_request_id(req_id)
# --> 176 return func(self, *args, **kwargs)
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/decorators.py:116, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#     114         back_off = min(back_off * back_off_multiplier, max_back_off)
#     115     else:
# --> 116         raise e from e
#     117 except Exception as e:
#     118     raise e from e
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/decorators.py:86, in retry_on_rpc_failure.<locals>.wrapper.<locals>.handler(*args, **kwargs)
#      84 while True:
#      85     try:
# ---> 86         return func(*args, **kwargs)
#      87     except grpc.RpcError as e:
#      88         # Do not retry on these codes
#      89         if e.code() in IGNORE_RETRY_CODES:
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/client/grpc_handler.py:1023, in GrpcHandler.create_index(self, collection_name, field_name, params, timeout, **kwargs)
#    1020     return index_future
#    1022 status = future.result()
# -> 1023 check_status(status)
#    1025 if kwargs.get("sync", True):
#    1026     index_success, fail_reason = self.wait_for_creating_index(
#    1027         collection_name=collection_name,
#    1028         index_name=index_name,
#    1029         timeout=timeout,
#    1030         field_name=field_name,
#    1031     )
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/pymilvus/client/utils.py:64, in check_status(status)
#      62 def check_status(status: Status):
#      63     if status.code != 0 or status.error_code != 0:
# ---> 64         raise MilvusException(status.code, status.reason, status.error_code)
#
# MilvusException: <MilvusException: (code=1100, message=create index on 104 field is not supported: invalid parameter[expected=supported field][actual=create index on 104 field])>

# %%
# Load collection into memory
collection.load()

# %%
# Example search
search_param = {
    "metric_type": "L2",
    "params": {"nprobe": 10}
}

# Example query using the first query from the dataset
results = collection.search(
    data=[queries[0]['text']],  # Using first query as example
    anns_field="text",
    param=search_param,
    limit=10
)

# Print results
for hits in results:
    for hit in hits:
        print(f"ID: {hit.id}, Distance: {hit.distance}")

# %%
import json

def corpus_to_jsonl(corpus, output_file):
    """
    Converts a corpus (list of dictionaries) to a JSONL file suitable for Pyserini indexing.

    Args:
        corpus (list): A list of dictionaries, where each dictionary represents a document.
                       Each document dictionary should have '_id' and 'full_text' keys.
        output_file (str): The path to the output JSONL file.
    """
    with open(output_file, 'w') as f_out:
        for doc in corpus:
            doc_id = doc['_id']
            text = doc['full_text']
            
            # Create a dictionary with 'id' and 'contents' keys
            output_dict = {'id': doc_id, 'contents': text}
            
            # Write the dictionary to the JSONL file as a JSON string
            json.dump(output_dict, f_out)
            f_out.write('\n')

# Example usage:
output_file = './data/trec_covid_corpus.jsonl'
corpus_to_jsonl(corpus, output_file)
print(f"Corpus converted to JSONL format and saved to {output_file}")
# Out:
# Corpus converted to JSONL format and saved to ./data/trec_covid_corpus.jsonl

# %% [markdown]
# ### build index

# %%
index_path = "./data/trec_covid_corpus_index"

# %%
# %%bash
# python -m pyserini.index.lucene --collection JsonCollection \
#     --generator DefaultLuceneDocumentGenerator \
#     --threads 4 \
#     --input "./data/trec_covid_corpus_input" \
#     --index "./data/trec_covid_corpus_index" \
#     --storePositions --storeDocvectors --storeRaw

# %% [markdown]
# ### Search

# %%
from pyserini.search.lucene import LuceneSearcher

searcher = LuceneSearcher('./data/trec_covid_corpus_index')

query_text = queries[0]['text']
hits = searcher.search(query_text, k=10)

for i in range(len(hits)):
    print(f'{i+1:2} {hits[i].docid:4} {hits[i].score:.5f}')
# Out:
#  1 dv9m19yk 7.27880
#  2 0paafp5j 6.22610
#  3 96zsd27n 6.22610
#  4 hmvo5b0q 6.11880
#  5 1ij25a7u 5.85120
#  6 5d7zien3 5.70360
#  7 fqs40ivc 5.66660
#  8 xqqn1t4e 5.64080
#  9 dckuhrlf 5.64070
# 10 h4vigeuy 5.63960

# %% [markdown]
# ### Search with RM3 query expansion

# %%
searcher.set_rm3()
hits = searcher.search(query_text, k=10)

for i in range(len(hits)):
    print(f'{i+1:2} {hits[i].docid:4} {hits[i].score:.5f}')
# Out:
#  1 dv9m19yk 1.51230
#  2 0paafp5j 1.47740
#  3 96zsd27n 1.47740
#  4 h4vigeuy 1.40550
#  5 fqs40ivc 1.35570
#  6 1ij25a7u 1.29020
#  7 37v59fs8 1.27120
#  8 5fg87lvu 1.26260
#  9 950x4b9a 1.26260
# 10 hmvo5b0q 1.25150

# %%
print(query_text)

print(searcher.is_using_rm3())

print(searcher.get_feedback_terms(query_text))
# Out:
# what is the origin of COVID-19
# True
# {'countri': 0.03179526701569557, 'covid': 0.125, 'what': 0.22162935137748718, 'origin': 0.19928449392318726, '19': 0.125, 'about': 0.03716013953089714, 'should': 0.04642285034060478, 'outbreak': 0.053088217973709106, 'global': 0.04541816934943199, 'event': 0.03194766864180565, 'research': 0.03683099523186684, 'anesthesia': 0.04642285034060478}

# %% [markdown]
# ### Gather search results

# %%
hits[0]
# Out:
# <io.anserini.search.ScoredDoc at 0x7f1ca2f22630 jclass=io/anserini/search/ScoredDoc jself=<LocalRef obj=0x384e401a at 0x7f1cfd526b30>>

# %%
BM25_retrieval_results = collections.defaultdict(dict)
top_k = 500
searcher.unset_rm3()
for query in queries:
    qid = query['_id']
    query_text = query['text']
    hits = searcher.search(query_text, k=top_k)
    
    docids = [hits[i].docid for i in range(top_k)]
    scores = [hits[i].score for i in range(top_k)]
    BM25_retrieval_results[qid] = dict(zip(docids, scores))

# %%
BM25_retrieval_results_RM3 = collections.defaultdict(dict)
top_k = 500
searcher.set_rm3()
for query in queries:
    qid = query['_id']
    query_text = query['text']
    hits = searcher.search(query_text, k=top_k)
    
    docids = [hits[i].docid for i in range(top_k)]
    scores = [hits[i].score for i in range(top_k)]
    BM25_retrieval_results_RM3[qid] = dict(zip(docids, scores))

# %% [markdown]
# ### EVal

# %%
qrels_for_eval = collections.defaultdict(dict)
for example in qrels['test']:
    qrels_for_eval[str(example['query-id'])][str(example['corpus-id'])] = example['score']

# %%
def eval_model(retrieval_results, qrels_for_eval):
    print(recall(qrels=qrels_for_eval, results=retrieval_results, k_values=[1, 3, 5, 10, 20, 30, 100, 500, 2000]))
    print(precision(qrels=qrels_for_eval, results=retrieval_results, k_values=[1, 3, 5, 10, 20, 30, 100, 500, 2000]))
    print(ndcg(qrels=qrels_for_eval, results=retrieval_results, k_values=[1, 3, 5, 10]))

# %%
eval_model(BM25_retrieval_results, qrels_for_eval)

# {'Recall@1': 0.00188, 'Recall@3': 0.00534, 'Recall@5': 0.00855, 'Recall@10': 0.01585, 'Recall@20': 0.02968, 'Recall@30': 0.043, 'Recall@100': 0.10896, 'Recall@500': 0.29329, 'Recall@2000': 0.29329}
# {'Precision@1': 0.76, 'Precision@3': 0.71333, 'Precision@5': 0.684, 'Precision@10': 0.646, 'Precision@20': 0.597, 'Precision@30': 0.576, 'Precision@100': 0.4712, 'Precision@500': 0.2766, 'Precision@2000': 0.06915}
# {'NDCG@1': 0.67, 'NDCG@3': 0.64801, 'NDCG@5': 0.63063, 'NDCG@10': 0.5995}
# Out:
# {'Recall@1': 0.00188, 'Recall@3': 0.00534, 'Recall@5': 0.00855, 'Recall@10': 0.01585, 'Recall@20': 0.02968, 'Recall@30': 0.043, 'Recall@100': 0.10896, 'Recall@500': 0.29329, 'Recall@2000': 0.29329}
# {'Precision@1': 0.76, 'Precision@3': 0.71333, 'Precision@5': 0.684, 'Precision@10': 0.646, 'Precision@20': 0.597, 'Precision@30': 0.576, 'Precision@100': 0.4712, 'Precision@500': 0.2766, 'Precision@2000': 0.06915}
# {'NDCG@1': 0.67, 'NDCG@3': 0.64801, 'NDCG@5': 0.63063, 'NDCG@10': 0.5995}

# %%
eval_model(BM25_retrieval_results_RM3, qrels_for_eval)

# using RM3 query expansion can improve recall, but will hurt precision and ranking
# {'Recall@1': 0.0018, 'Recall@3': 0.0053, 'Recall@5': 0.00873, 'Recall@10': 0.01646, 'Recall@20': 0.03072, 'Recall@30': 0.04298, 'Recall@100': 0.1181, 'Recall@500': 0.33463, 'Recall@2000': 0.33463}
# {'Precision@1': 0.74, 'Precision@3': 0.71333, 'Precision@5': 0.704, 'Precision@10': 0.662, 'Precision@20': 0.62, 'Precision@30': 0.59, 'Precision@100': 0.5, 'Precision@500': 0.30824, 'Precision@2000': 0.07706}
# {'NDCG@1': 0.64, 'NDCG@3': 0.62561, 'NDCG@5': 0.61974, 'NDCG@10': 0.59406}
# Out:
# {'Recall@1': 0.0018, 'Recall@3': 0.0053, 'Recall@5': 0.00873, 'Recall@10': 0.01646, 'Recall@20': 0.03072, 'Recall@30': 0.04298, 'Recall@100': 0.1181, 'Recall@500': 0.33463, 'Recall@2000': 0.33463}
# {'Precision@1': 0.74, 'Precision@3': 0.71333, 'Precision@5': 0.704, 'Precision@10': 0.662, 'Precision@20': 0.62, 'Precision@30': 0.59, 'Precision@100': 0.5, 'Precision@500': 0.30824, 'Precision@2000': 0.07706}
# {'NDCG@1': 0.64, 'NDCG@3': 0.62561, 'NDCG@5': 0.61974, 'NDCG@10': 0.59406}

# %% [markdown]
# ### Inspect BM25 index
# https://github.com/castorini/pyserini/blob/master/docs/usage-indexreader.md#how-do-i-iterate-over-index-terms-and-access-term-statistics

# %%
from pyserini.index.lucene import LuceneIndexReader

# %%
# Initialize from an index path:
index_reader = LuceneIndexReader(index_path)

# %%
# get access to basic stats
index_reader.stats()
# Out:
# {'total_terms': 21165485,
#  'documents': 171332,
#  'non_empty_documents': 171332,
#  'unique_terms': 202648}

# %%
import itertools
for term in itertools.islice(index_reader.terms(), 100):
    print(f'{term.term} (df={term.df}, cf={term.cf})')
# Out:
# 0 (df=4571, cf=8586)
# 0,00 (df=1, cf=1)
# 0,000 (df=1, cf=1)
# 0,0001 (df=6, cf=7)
# 0,0002 (df=1, cf=1)
# 0,0004 (df=2, cf=2)
# 0,0005 (df=1, cf=1)
# 0,0006 (df=1, cf=1)
# 0,0007 (df=1, cf=1)
# 0,001 (df=16, cf=28)
# 0,0010 (df=1, cf=1)
# 0,0013 (df=1, cf=1)
# 0,002 (df=5, cf=5)
# 0,003 (df=2, cf=2)
# 0,0033 (df=1, cf=1)
# 0,0037 (df=1, cf=1)
# 0,004 (df=1, cf=1)
# 0,0041 (df=1, cf=1)
# 0,0043 (df=2, cf=2)
# 0,005 (df=6, cf=6)
# 0,006 (df=3, cf=4)
# 0,007 (df=2, cf=2)
# 0,009 (df=1, cf=1)
# 0,01 (df=9, cf=9)
# 0,013 (df=1, cf=1)
# 0,014 (df=1, cf=1)
# 0,015 (df=2, cf=2)
# 0,018 (df=2, cf=2)
# 0,02 (df=3, cf=5)
# 0,0202 (df=1, cf=1)
# 0,024 (df=1, cf=1)
# 0,026 (df=1, cf=1)
# 0,027 (df=1, cf=1)
# 0,029 (df=1, cf=1)
# 0,03 (df=5, cf=5)
# 0,031 (df=1, cf=1)
# 0,033 (df=1, cf=1)
# 0,036 (df=2, cf=2)
# 0,038 (df=1, cf=1)
# 0,04 (df=2, cf=5)
# 0,043 (df=1, cf=1)
# 0,044 (df=1, cf=1)
# 0,045 (df=2, cf=2)
# 0,048 (df=2, cf=2)
# 0,049 (df=1, cf=2)
# 0,05 (df=17, cf=22)
# 0,052 (df=1, cf=1)
# 0,054 (df=1, cf=1)
# 0,060 (df=1, cf=1)
# 0,0651 (df=1, cf=1)
# 0,069 (df=1, cf=1)
# 0,07 (df=1, cf=1)
# 0,08 (df=1, cf=1)
# 0,089 (df=1, cf=1)
# 0,09 (df=1, cf=2)
# 0,1 (df=5, cf=5)
# 0,1,1 (df=1, cf=1)
# 0,1,2 (df=1, cf=1)
# 0,13 (df=2, cf=2)
# 0,14 (df=1, cf=1)
# 0,15 (df=1, cf=1)
# 0,170 (df=1, cf=1)
# 0,173 (df=1, cf=1)
# 0,18 (df=1, cf=1)
# 0,19 (df=1, cf=1)
# 0,1m (df=1, cf=1)
# 0,2 (df=10, cf=10)
# 0,2,1 (df=3, cf=5)
# 0,22 (df=2, cf=3)
# 0,23 (df=1, cf=1)
# 0,25 (df=1, cf=1)
# 0,257 (df=1, cf=1)
# 0,28 (df=1, cf=1)
# 0,29 (df=1, cf=1)
# 0,3 (df=3, cf=3)
# 0,3,1 (df=1, cf=2)
# 0,30 (df=3, cf=3)
# 0,32 (df=1, cf=1)
# 0,33 (df=1, cf=1)
# 0,35 (df=3, cf=3)
# 0,36 (df=1, cf=1)
# 0,37 (df=1, cf=1)
# 0,38 (df=1, cf=1)
# 0,39 (df=1, cf=1)
# 0,4 (df=4, cf=4)
# 0,40 (df=1, cf=1)
# 0,42 (df=4, cf=5)
# 0,43 (df=1, cf=1)
# 0,45 (df=2, cf=2)
# 0,47 (df=2, cf=2)
# 0,48 (df=1, cf=1)
# 0,49 (df=1, cf=1)
# 0,5 (df=6, cf=6)
# 0,50 (df=1, cf=1)
# 0,500 (df=1, cf=2)
# 0,506 (df=1, cf=1)
# 0,5459 (df=1, cf=1)
# 0,55 (df=1, cf=1)
# 0,57 (df=1, cf=1)
# 0,5ml (df=1, cf=1)

# %%
term = 'cities'

# Look up its document frequency (df) and collection frequency (cf).
# Note, we use the unanalyzed form:
df, cf = index_reader.get_term_counts(term)
print(f'term "{term}": df={df}, cf={cf}')
# Out:
# term "cities": df=3277, cf=5556

# %%
# Here's how to fetch and traverse postings:
# Fetch and traverse postings for an unanalyzed term:
postings_list = index_reader.get_postings_list(term)
print(len(postings_list))
for posting in postings_list:
    # position is where is the token at the document
    print(f'docid={posting.docid}, tf={posting.tf}, pos={posting.positions}')
# Out:
# 3277
# docid=68, tf=2, pos=[220, 236]
# docid=140, tf=1, pos=[151]
# docid=189, tf=1, pos=[81]
# docid=349, tf=1, pos=[219]
# docid=364, tf=1, pos=[39]
# docid=394, tf=1, pos=[181]
# docid=438, tf=2, pos=[171, 185]
# docid=496, tf=2, pos=[81, 87]
# docid=497, tf=8, pos=[60, 62, 79, 88, 90, 115, 163, 200]
# docid=587, tf=1, pos=[68]
# docid=655, tf=1, pos=[260]
# docid=691, tf=1, pos=[95]
# docid=743, tf=3, pos=[17, 63, 137]
# docid=806, tf=2, pos=[13, 89]
# docid=936, tf=2, pos=[41, 74]
# docid=976, tf=1, pos=[70]
# docid=1005, tf=1, pos=[118]
# docid=1030, tf=3, pos=[19, 31, 72]
# docid=1091, tf=1, pos=[48]
# docid=1105, tf=1, pos=[175]
# docid=1114, tf=2, pos=[95, 106]
# docid=1355, tf=1, pos=[133]
# docid=1368, tf=1, pos=[54]
# docid=1425, tf=1, pos=[91]
# docid=1435, tf=2, pos=[93, 281]
# docid=1620, tf=5, pos=[11, 83, 139, 181, 227]
# docid=1623, tf=1, pos=[17]
# docid=1698, tf=1, pos=[128]
# docid=1736, tf=6, pos=[12, 90, 127, 133, 167, 219]
# docid=1792, tf=2, pos=[150, 163]
# docid=1817, tf=1, pos=[67]
# docid=1893, tf=1, pos=[74]
# docid=1973, tf=1, pos=[184]
# docid=1974, tf=1, pos=[173]
# docid=2022, tf=2, pos=[35, 257]
# docid=2091, tf=1, pos=[60]
# docid=2143, tf=1, pos=[167]
# docid=2164, tf=1, pos=[40]
# docid=2269, tf=4, pos=[184, 191, 202, 220]
# docid=2276, tf=1, pos=[14]
# docid=2322, tf=1, pos=[134]
# docid=2370, tf=1, pos=[231]
# docid=2393, tf=4, pos=[18, 75, 186, 277]
# docid=2407, tf=1, pos=[90]
# docid=2448, tf=2, pos=[24, 55]
# docid=2544, tf=3, pos=[27, 86, 96]
# docid=2595, tf=1, pos=[94]
# docid=2733, tf=1, pos=[70]
# docid=2790, tf=1, pos=[208]
# docid=2961, tf=1, pos=[121]
# docid=3137, tf=1, pos=[91]
# docid=3553, tf=1, pos=[53]
# docid=3590, tf=1, pos=[160]
# docid=3615, tf=1, pos=[94]
# docid=3662, tf=1, pos=[146]
# docid=3775, tf=1, pos=[69]
# docid=3834, tf=1, pos=[206]
# docid=3881, tf=2, pos=[36, 87]
# docid=4093, tf=1, pos=[12]
# docid=4378, tf=1, pos=[192]
# docid=4410, tf=1, pos=[20]
# docid=4588, tf=4, pos=[12, 34, 170, 190]
# docid=4818, tf=4, pos=[13, 36, 52, 165]
# docid=5024, tf=1, pos=[63]
# docid=5179, tf=2, pos=[5, 38]
# docid=5365, tf=1, pos=[134]
# docid=5384, tf=1, pos=[178]
# docid=5446, tf=2, pos=[4, 37]
# docid=5465, tf=1, pos=[158]
# docid=5542, tf=2, pos=[65, 89]
# docid=5867, tf=1, pos=[11]
# docid=5904, tf=1, pos=[41]
# docid=5940, tf=1, pos=[16]
# docid=6252, tf=1, pos=[85]
# docid=6859, tf=1, pos=[94]
# docid=7329, tf=2, pos=[89, 114]
# docid=7455, tf=1, pos=[21]
# docid=7608, tf=1, pos=[40]
# docid=7611, tf=3, pos=[15, 40, 99]
# docid=7628, tf=1, pos=[161]
# docid=8045, tf=1, pos=[73]
# docid=8435, tf=2, pos=[22, 69]
# docid=8614, tf=3, pos=[5, 31, 112]
# docid=8852, tf=2, pos=[42, 109]
# docid=9751, tf=1, pos=[24]
# docid=9928, tf=2, pos=[96, 249]
# docid=10492, tf=1, pos=[111]
# docid=10731, tf=1, pos=[20]
# docid=10904, tf=1, pos=[138]
# docid=10972, tf=1, pos=[15]
# docid=11126, tf=2, pos=[27, 79]
# docid=11133, tf=4, pos=[104, 122, 189, 214]
# docid=11194, tf=1, pos=[75]
# docid=11608, tf=3, pos=[6, 129, 203]
# docid=11722, tf=1, pos=[67]
# docid=11810, tf=1, pos=[38]
# docid=11850, tf=3, pos=[44, 59, 94]
# docid=12003, tf=1, pos=[142]
# docid=12013, tf=2, pos=[118, 138]
# docid=12016, tf=1, pos=[144]
# docid=12063, tf=1, pos=[46]
# docid=12290, tf=2, pos=[9055, 10985]
# docid=12301, tf=1, pos=[480]
# docid=12330, tf=1, pos=[22]
# docid=12383, tf=1, pos=[67]
# docid=12419, tf=1, pos=[66]
# docid=12521, tf=1, pos=[115]
# docid=12692, tf=1, pos=[61]
# docid=13036, tf=1, pos=[156]
# docid=13107, tf=2, pos=[23, 51]
# docid=13146, tf=1, pos=[143]
# docid=13498, tf=2, pos=[35, 111]
# docid=13911, tf=2, pos=[35, 108]
# docid=13924, tf=3, pos=[8, 86, 105]
# docid=13931, tf=4, pos=[2, 20, 45, 66]
# docid=13978, tf=1, pos=[159]
# docid=14039, tf=1, pos=[106]
# docid=14127, tf=1, pos=[66]
# docid=14140, tf=1, pos=[238]
# docid=14251, tf=2, pos=[69, 126]
# docid=14451, tf=7, pos=[2, 8, 34, 72, 162, 183, 234]
# docid=14479, tf=1, pos=[53]
# docid=14554, tf=2, pos=[125, 132]
# docid=14698, tf=1, pos=[37]
# docid=14700, tf=1, pos=[180]
# docid=14792, tf=1, pos=[19]
# docid=14826, tf=1, pos=[193]
# docid=14901, tf=2, pos=[9, 98]
# docid=14916, tf=1, pos=[87]
# docid=14945, tf=4, pos=[6, 30, 72, 162]
# docid=14951, tf=1, pos=[27]
# docid=15218, tf=1, pos=[34]
# docid=15221, tf=2, pos=[19, 122]
# docid=15359, tf=1, pos=[106]
# docid=15419, tf=5, pos=[8, 27, 287, 332, 335]
# docid=15425, tf=1, pos=[135]
# docid=15629, tf=1, pos=[154]
# docid=15633, tf=1, pos=[216]
# docid=15642, tf=1, pos=[121]
# docid=15692, tf=1, pos=[197]
# docid=15719, tf=1, pos=[10]
# docid=15748, tf=4, pos=[32, 59, 69, 82]
# docid=15758, tf=1, pos=[71]
# docid=15917, tf=1, pos=[174]
# docid=15939, tf=2, pos=[68, 87]
# docid=16023, tf=1, pos=[84]
# docid=16069, tf=1, pos=[93]
# docid=16075, tf=2, pos=[30, 38]
# docid=16135, tf=4, pos=[2, 43, 58, 99]
# docid=16147, tf=1, pos=[59]
# docid=16180, tf=1, pos=[148]
# docid=16257, tf=1, pos=[37]
# docid=16312, tf=1, pos=[51]
# docid=16363, tf=5, pos=[11, 25, 61, 102, 105]
# docid=16374, tf=2, pos=[45, 49]
# docid=16388, tf=3, pos=[4, 25, 42]
# docid=16406, tf=1, pos=[226]
# docid=16494, tf=1, pos=[134]
# docid=16501, tf=7, pos=[94, 103, 125, 130, 138, 160, 208]
# docid=16528, tf=1, pos=[86]
# docid=16537, tf=2, pos=[33, 78]
# docid=16589, tf=2, pos=[113, 182]
# docid=16879, tf=1, pos=[16]
# docid=17672, tf=10, pos=[2, 24, 32, 44, 76, 154, 160, 173, 174, 176]
# docid=17693, tf=4, pos=[65, 95, 118, 148]
# docid=17712, tf=9, pos=[11, 15, 64, 81, 108, 135, 158, 165, 176]
# docid=17717, tf=2, pos=[14, 74]
# docid=17733, tf=3, pos=[25, 60, 173]
# docid=17950, tf=1, pos=[12]
# docid=18104, tf=4, pos=[15, 121, 127, 192]
# docid=18232, tf=1, pos=[140]
# docid=18233, tf=1, pos=[154]
# docid=18826, tf=3, pos=[10, 78, 210]
# docid=18961, tf=1, pos=[49]
# docid=18999, tf=1, pos=[22]
# docid=19212, tf=1, pos=[107]
# docid=19538, tf=3, pos=[12, 169, 195]
# docid=19590, tf=1, pos=[79]
# docid=20087, tf=2, pos=[12, 35]
# docid=20095, tf=1, pos=[22]
# docid=20105, tf=1, pos=[10]
# docid=20656, tf=1, pos=[1]
# docid=21207, tf=2, pos=[75, 95]
# docid=21272, tf=1, pos=[40]
# docid=21275, tf=1, pos=[28]
# docid=21276, tf=1, pos=[30]
# docid=21449, tf=1, pos=[65]
# docid=21541, tf=1, pos=[59]
# docid=21557, tf=1, pos=[240]
# docid=21838, tf=1, pos=[114]
# docid=21848, tf=1, pos=[6]
# docid=21976, tf=1, pos=[201]
# docid=22099, tf=2, pos=[36, 143]
# docid=22554, tf=1, pos=[18]
# docid=22584, tf=1, pos=[154]
# docid=22597, tf=1, pos=[57]
# docid=22600, tf=1, pos=[125]
# docid=22621, tf=4, pos=[8, 11, 30, 52]
# docid=22666, tf=1, pos=[18]
# docid=22673, tf=1, pos=[59]
# docid=22911, tf=1, pos=[17]
# docid=22970, tf=2, pos=[141, 279]
# docid=23068, tf=1, pos=[44]
# docid=23181, tf=1, pos=[9]
# docid=23259, tf=1, pos=[41]
# docid=23302, tf=2, pos=[7, 28]
# docid=23367, tf=7, pos=[6, 24, 41, 50, 119, 148, 172]
# docid=23381, tf=2, pos=[2, 28]
# docid=23382, tf=2, pos=[3, 16]
# docid=23383, tf=3, pos=[4, 21, 38]
# docid=23384, tf=3, pos=[15, 26, 30]
# docid=23388, tf=3, pos=[6, 11, 31]
# docid=23554, tf=1, pos=[90]
# docid=23603, tf=1, pos=[7]
# docid=23702, tf=2, pos=[300, 303]
# docid=23931, tf=2, pos=[19, 43]
# docid=23955, tf=1, pos=[42]
# docid=24085, tf=1, pos=[186]
# docid=24115, tf=1, pos=[107]
# docid=24132, tf=1, pos=[43]
# docid=24146, tf=1, pos=[37]
# docid=24372, tf=1, pos=[53]
# docid=24437, tf=1, pos=[164]
# docid=24489, tf=1, pos=[47]
# docid=24639, tf=3, pos=[18, 45, 166]
# docid=24647, tf=1, pos=[83]
# docid=24788, tf=1, pos=[106]
# docid=24797, tf=1, pos=[93]
# docid=24834, tf=1, pos=[9]
# docid=24951, tf=1, pos=[167]
# docid=24967, tf=1, pos=[11]
# docid=24977, tf=1, pos=[62]
# docid=24996, tf=1, pos=[58]
# docid=25131, tf=1, pos=[15]
# docid=25276, tf=2, pos=[237, 304]
# docid=25394, tf=1, pos=[105]
# docid=25432, tf=5, pos=[35, 68, 74, 102, 122]
# docid=25701, tf=2, pos=[16, 112]
# docid=25719, tf=8, pos=[12, 60, 90, 94, 145, 178, 190, 200]
# docid=25814, tf=1, pos=[158]
# docid=25959, tf=1, pos=[29]
# docid=26061, tf=1, pos=[4]
# docid=26089, tf=1, pos=[48]
# docid=26115, tf=2, pos=[9, 49]
# docid=26193, tf=1, pos=[91]
# docid=26306, tf=3, pos=[88, 93, 131]
# docid=26495, tf=1, pos=[54]
# docid=26539, tf=1, pos=[16]
# docid=26547, tf=7, pos=[18, 35, 103, 154, 164, 186, 249]
# docid=26603, tf=2, pos=[192, 284]
# docid=26621, tf=1, pos=[41]
# docid=26622, tf=1, pos=[3]
# docid=26642, tf=3, pos=[10, 38, 137]
# docid=26652, tf=2, pos=[18, 75]
# docid=26701, tf=1, pos=[56]
# docid=26810, tf=2, pos=[20, 46]
# docid=26974, tf=1, pos=[85]
# docid=27073, tf=3, pos=[13, 35, 69]
# docid=27085, tf=1, pos=[41]
# docid=27119, tf=1, pos=[27]
# docid=27163, tf=1, pos=[23]
# docid=27174, tf=1, pos=[69]
# docid=27356, tf=2, pos=[10, 44]
# docid=27375, tf=1, pos=[170]
# docid=27405, tf=1, pos=[7]
# docid=27605, tf=1, pos=[31]
# docid=27618, tf=1, pos=[223]
# docid=27916, tf=1, pos=[23]
# docid=28215, tf=1, pos=[206]
# docid=28221, tf=1, pos=[78]
# docid=28286, tf=1, pos=[17]
# docid=28345, tf=1, pos=[187]
# docid=28452, tf=1, pos=[65]
# docid=28470, tf=1, pos=[44]
# docid=28544, tf=1, pos=[30]
# docid=28831, tf=2, pos=[18, 69]
# docid=28922, tf=1, pos=[12]
# docid=28982, tf=1, pos=[56]
# docid=29169, tf=1, pos=[102]
# docid=29373, tf=1, pos=[44]
# docid=29397, tf=2, pos=[3, 6]
# docid=29402, tf=1, pos=[153]
# docid=29421, tf=1, pos=[51]
# docid=29942, tf=3, pos=[35, 100, 115]
# docid=30367, tf=2, pos=[16, 258]
# docid=30743, tf=1, pos=[120]
# docid=30886, tf=1, pos=[86]
# docid=30915, tf=1, pos=[13]
# docid=30953, tf=1, pos=[106]
# docid=30966, tf=1, pos=[14]
# docid=31074, tf=1, pos=[50]
# docid=31280, tf=1, pos=[63]
# docid=31291, tf=1, pos=[28]
# docid=31321, tf=1, pos=[171]
# docid=31344, tf=2, pos=[43, 148]
# docid=31352, tf=1, pos=[37]
# docid=31698, tf=1, pos=[23]
# docid=31715, tf=1, pos=[53]
# docid=31789, tf=3, pos=[70, 132, 191]
# docid=31801, tf=2, pos=[10, 25]
# docid=31839, tf=1, pos=[72]
# docid=31947, tf=1, pos=[17]
# docid=32057, tf=2, pos=[12, 27]
# docid=32137, tf=1, pos=[63]
# docid=32178, tf=1, pos=[244]
# docid=32296, tf=1, pos=[170]
# docid=32510, tf=2, pos=[34, 66]
# docid=32588, tf=5, pos=[4, 102, 156, 257, 294]
# docid=32686, tf=1, pos=[71]
# docid=32753, tf=4, pos=[13, 69, 86, 190]
# docid=32880, tf=1, pos=[57]
# docid=32949, tf=1, pos=[71]
# docid=33037, tf=1, pos=[256]
# docid=33042, tf=1, pos=[412]
# docid=33233, tf=1, pos=[80]
# docid=33237, tf=2, pos=[11, 88]
# docid=33284, tf=1, pos=[35]
# docid=33370, tf=1, pos=[125]
# docid=33422, tf=1, pos=[7]
# docid=33676, tf=2, pos=[28, 62]
# docid=33807, tf=3, pos=[45, 145, 236]
# docid=33838, tf=1, pos=[172]
# docid=33883, tf=1, pos=[32]
# docid=34012, tf=4, pos=[24, 55, 93, 260]
# docid=34137, tf=1, pos=[80]
# docid=34171, tf=1, pos=[29]
# docid=34172, tf=1, pos=[58]
# docid=34214, tf=1, pos=[193]
# docid=34224, tf=1, pos=[97]
# docid=34315, tf=4, pos=[18, 20, 53, 55]
# docid=34327, tf=4, pos=[5, 47, 85, 103]
# docid=34373, tf=2, pos=[27, 43]
# docid=34431, tf=2, pos=[72, 121]
# docid=34542, tf=1, pos=[124]
# docid=34715, tf=1, pos=[11]
# docid=34740, tf=3, pos=[12, 182, 219]
# docid=34755, tf=1, pos=[78]
# docid=34767, tf=1, pos=[70]
# docid=34850, tf=1, pos=[1]
# docid=34894, tf=1, pos=[55]
# docid=35101, tf=1, pos=[20]
# docid=35268, tf=1, pos=[122]
# docid=35812, tf=1, pos=[34]
# docid=35822, tf=1, pos=[104]
# docid=35888, tf=2, pos=[107, 134]
# docid=35992, tf=1, pos=[78]
# docid=36025, tf=1, pos=[96]
# docid=36134, tf=2, pos=[13, 113]
# docid=36470, tf=3, pos=[17, 54, 115]
# docid=36735, tf=1, pos=[93]
# docid=36896, tf=1, pos=[109]
# docid=36917, tf=1, pos=[29]
# docid=37048, tf=1, pos=[50]
# docid=37192, tf=1, pos=[18]
# docid=37207, tf=1, pos=[38]
# docid=37262, tf=1, pos=[21]
# docid=37343, tf=1, pos=[16]
# docid=37384, tf=1, pos=[11]
# docid=37431, tf=1, pos=[127]
# docid=37526, tf=2, pos=[37, 129]
# docid=37660, tf=1, pos=[56]
# docid=37744, tf=2, pos=[24, 100]
# docid=37798, tf=1, pos=[110]
# docid=37963, tf=1, pos=[49]
# docid=38108, tf=1, pos=[26]
# docid=38202, tf=1, pos=[55]
# docid=38303, tf=1, pos=[96]
# docid=38504, tf=2, pos=[15, 112]
# docid=38606, tf=1, pos=[30]
# docid=38666, tf=1, pos=[53]
# docid=38673, tf=1, pos=[33]
# docid=38714, tf=1, pos=[20]
# docid=38962, tf=3, pos=[18, 99, 155]
# docid=39078, tf=1, pos=[8]
# docid=39148, tf=2, pos=[118, 138]
# docid=39165, tf=3, pos=[16, 65, 145]
# docid=39282, tf=1, pos=[189]
# docid=39294, tf=1, pos=[200]
# docid=39921, tf=1, pos=[31]
# docid=39953, tf=3, pos=[18, 46, 64]
# docid=40021, tf=1, pos=[12]
# docid=40168, tf=1, pos=[11]
# docid=40184, tf=2, pos=[13, 32]
# docid=40389, tf=1, pos=[100]
# docid=40461, tf=1, pos=[226]
# docid=40482, tf=1, pos=[39]
# docid=40598, tf=1, pos=[49]
# docid=40785, tf=1, pos=[12]
# docid=40819, tf=1, pos=[67]
# docid=40841, tf=4, pos=[9, 63, 135, 160]
# docid=40847, tf=1, pos=[167]
# docid=40871, tf=1, pos=[157]
# docid=41323, tf=1, pos=[71]
# docid=41592, tf=1, pos=[35]
# docid=41609, tf=2, pos=[130, 137]
# docid=41747, tf=1, pos=[89]
# docid=41750, tf=3, pos=[51, 84, 137]
# docid=41788, tf=1, pos=[152]
# docid=41810, tf=1, pos=[99]
# docid=41845, tf=2, pos=[7, 13]
# docid=41920, tf=1, pos=[33]
# docid=42048, tf=1, pos=[54]
# docid=42207, tf=1, pos=[29]
# docid=42254, tf=3, pos=[17, 50, 85]
# docid=42286, tf=1, pos=[264]
# docid=42482, tf=1, pos=[150]
# docid=42517, tf=1, pos=[14]
# docid=42582, tf=3, pos=[18, 39, 68]
# docid=42999, tf=2, pos=[18, 47]
# docid=43189, tf=1, pos=[50]
# docid=43271, tf=1, pos=[115]
# docid=43334, tf=1, pos=[57]
# docid=43583, tf=2, pos=[21, 46]
# docid=43599, tf=1, pos=[40]
# docid=43931, tf=1, pos=[19]
# docid=44089, tf=3, pos=[17, 80, 400]
# docid=44135, tf=1, pos=[298]
# docid=44245, tf=1, pos=[5]
# docid=44384, tf=1, pos=[40]
# docid=44493, tf=1, pos=[57]
# docid=44628, tf=1, pos=[46]
# docid=44797, tf=1, pos=[170]
# docid=44812, tf=1, pos=[49]
# docid=44882, tf=1, pos=[42]
# docid=44939, tf=1, pos=[97]
# docid=44961, tf=1, pos=[13]
# docid=44979, tf=2, pos=[9, 21]
# docid=45000, tf=1, pos=[180]
# docid=45092, tf=3, pos=[119, 166, 187]
# docid=45138, tf=1, pos=[23]
# docid=45216, tf=1, pos=[108]
# docid=45241, tf=2, pos=[77, 138]
# docid=45276, tf=1, pos=[264]
# docid=45307, tf=4, pos=[12, 41, 113, 204]
# docid=45335, tf=1, pos=[101]
# docid=45448, tf=2, pos=[136, 145]
# docid=45505, tf=3, pos=[132, 138, 163]
# docid=45532, tf=4, pos=[23, 62, 173, 236]
# docid=45583, tf=1, pos=[37]
# docid=45637, tf=1, pos=[123]
# docid=45807, tf=1, pos=[86]
# docid=45880, tf=3, pos=[13, 29, 109]
# docid=45986, tf=2, pos=[12, 66]
# docid=45988, tf=1, pos=[57]
# docid=46090, tf=1, pos=[91]
# docid=46267, tf=1, pos=[23]
# docid=46321, tf=1, pos=[30]
# docid=46582, tf=1, pos=[26]
# docid=46760, tf=1, pos=[106]
# docid=46806, tf=1, pos=[96]
# docid=46909, tf=1, pos=[48]
# docid=47039, tf=1, pos=[39]
# docid=47158, tf=1, pos=[34]
# docid=47166, tf=2, pos=[16, 157]
# docid=47194, tf=5, pos=[8, 32, 50, 66, 81]
# docid=47419, tf=1, pos=[24]
# docid=47973, tf=2, pos=[74, 211]
# docid=48184, tf=3, pos=[58, 78, 187]
# docid=48192, tf=1, pos=[121]
# docid=48354, tf=1, pos=[123]
# docid=48361, tf=1, pos=[64]
# docid=48485, tf=1, pos=[103]
# docid=48530, tf=1, pos=[64]
# docid=48533, tf=3, pos=[32, 100, 183]
# docid=48664, tf=1, pos=[44]
# docid=48691, tf=1, pos=[71]
# docid=48847, tf=1, pos=[49]
# docid=49409, tf=1, pos=[6]
# docid=49463, tf=1, pos=[107]
# docid=49551, tf=1, pos=[105]
# docid=49689, tf=2, pos=[143, 150]
# docid=49755, tf=1, pos=[86]
# docid=49856, tf=3, pos=[248, 270, 335]
# docid=49957, tf=1, pos=[91]
# docid=49997, tf=1, pos=[12]
# docid=50050, tf=1, pos=[76]
# docid=50103, tf=1, pos=[29]
# docid=50368, tf=1, pos=[18]
# docid=50424, tf=1, pos=[40]
# docid=50530, tf=2, pos=[28, 96]
# docid=50546, tf=1, pos=[32]
# docid=50681, tf=1, pos=[164]
# docid=50746, tf=5, pos=[14, 64, 205, 222, 243]
# docid=50869, tf=7, pos=[73, 88, 112, 147, 168, 194, 264]
# docid=51143, tf=2, pos=[2, 51]
# docid=51202, tf=1, pos=[34]
# docid=51816, tf=4, pos=[51, 170, 210, 258]
# docid=52314, tf=2, pos=[127, 168]
# docid=52370, tf=1, pos=[2]
# docid=52719, tf=1, pos=[48]
# docid=52800, tf=1, pos=[62]
# docid=52855, tf=2, pos=[8, 17]
# docid=53070, tf=1, pos=[34]
# docid=53090, tf=1, pos=[4]
# docid=53171, tf=1, pos=[76]
# docid=53290, tf=1, pos=[16]
# docid=53329, tf=1, pos=[152]
# docid=53544, tf=2, pos=[88, 142]
# docid=53595, tf=1, pos=[28]
# docid=53639, tf=1, pos=[56]
# docid=53642, tf=2, pos=[27, 88]
# docid=53763, tf=1, pos=[104]
# docid=53827, tf=1, pos=[49]
# docid=53878, tf=3, pos=[13, 19, 196]
# docid=53978, tf=1, pos=[84]
# docid=54422, tf=4, pos=[13, 32, 59, 277]
# docid=54452, tf=1, pos=[31]
# docid=54581, tf=1, pos=[35]
# docid=54609, tf=1, pos=[58]
# docid=54663, tf=2, pos=[21, 75]
# docid=54785, tf=1, pos=[21]
# docid=54903, tf=1, pos=[243]
# docid=55054, tf=5, pos=[9, 44, 67, 122, 143]
# docid=55127, tf=3, pos=[27, 57, 286]
# docid=55244, tf=1, pos=[4]
# docid=55269, tf=1, pos=[14]
# docid=55335, tf=1, pos=[61]
# docid=55401, tf=1, pos=[106]
# docid=55576, tf=1, pos=[139]
# docid=55584, tf=2, pos=[11, 199]
# docid=55889, tf=1, pos=[14]
# docid=55919, tf=1, pos=[62]
# docid=56013, tf=1, pos=[27]
# docid=56015, tf=1, pos=[8]
# docid=56093, tf=1, pos=[54]
# docid=56115, tf=1, pos=[49]
# docid=56136, tf=3, pos=[10, 35, 43]
# docid=56184, tf=2, pos=[48, 77]
# docid=56189, tf=1, pos=[26]
# docid=56405, tf=1, pos=[261]
# docid=56510, tf=1, pos=[12]
# docid=56649, tf=1, pos=[33]
# docid=56679, tf=1, pos=[53]
# docid=56681, tf=1, pos=[22]
# docid=56699, tf=2, pos=[143, 344]
# docid=56779, tf=1, pos=[39]
# docid=56812, tf=3, pos=[12, 15, 42]
# docid=56866, tf=1, pos=[10]
# docid=56899, tf=1, pos=[74]
# docid=57059, tf=1, pos=[15]
# docid=57147, tf=1, pos=[99]
# docid=57276, tf=1, pos=[194]
# docid=57645, tf=1, pos=[34]
# docid=57646, tf=1, pos=[25]
# docid=57676, tf=1, pos=[113]
# docid=57754, tf=1, pos=[124]
# docid=57831, tf=9, pos=[12, 30, 48, 70, 150, 157, 216, 257, 290]
# docid=57968, tf=3, pos=[13, 64, 166]
# docid=58203, tf=1, pos=[72]
# docid=58247, tf=1, pos=[47]
# docid=58330, tf=1, pos=[21]
# docid=58551, tf=3, pos=[18, 69, 129]
# docid=58588, tf=1, pos=[40]
# docid=58612, tf=1, pos=[85]
# docid=58661, tf=2, pos=[3, 23]
# docid=58706, tf=1, pos=[109]
# docid=58748, tf=1, pos=[51]
# docid=58762, tf=1, pos=[72]
# docid=58874, tf=1, pos=[92]
# docid=58918, tf=1, pos=[64]
# docid=59053, tf=1, pos=[122]
# docid=59104, tf=1, pos=[186]
# docid=59117, tf=1, pos=[416]
# docid=59297, tf=3, pos=[25, 43, 46]
# docid=59751, tf=1, pos=[35]
# docid=60047, tf=5, pos=[34, 52, 98, 104, 176]
# docid=60062, tf=1, pos=[84]
# docid=60075, tf=2, pos=[22, 105]
# docid=60171, tf=1, pos=[42]
# docid=60448, tf=1, pos=[32]
# docid=60480, tf=6, pos=[33, 41, 68, 94, 130, 229]
# docid=60652, tf=3, pos=[27, 52, 60]
# docid=60928, tf=1, pos=[159]
# docid=60983, tf=4, pos=[84, 128, 225, 288]
# docid=61057, tf=1, pos=[22]
# docid=61283, tf=1, pos=[48]
# docid=61562, tf=1, pos=[44]
# docid=61585, tf=1, pos=[100]
# docid=61712, tf=1, pos=[149]
# docid=61838, tf=3, pos=[35, 58, 159]
# docid=61858, tf=2, pos=[186, 200]
# docid=62263, tf=1, pos=[10]
# docid=62447, tf=1, pos=[29]
# docid=62451, tf=1, pos=[49]
# docid=62565, tf=1, pos=[74]
# docid=62729, tf=1, pos=[24]
# docid=62911, tf=2, pos=[74, 292]
# docid=63216, tf=1, pos=[44]
# docid=63246, tf=1, pos=[120]
# docid=63259, tf=1, pos=[101]
# docid=63307, tf=1, pos=[19]
# docid=63421, tf=1, pos=[152]
# docid=63762, tf=1, pos=[41]
# docid=63783, tf=1, pos=[25]
# docid=63844, tf=1, pos=[36]
# docid=64097, tf=1, pos=[132]
# docid=64114, tf=1, pos=[39]
# docid=64591, tf=1, pos=[29]
# docid=64646, tf=3, pos=[71, 98, 167]
# docid=64955, tf=1, pos=[161]
# docid=65155, tf=1, pos=[127]
# docid=65177, tf=1, pos=[90]
# docid=65330, tf=1, pos=[86]
# docid=65334, tf=4, pos=[32, 85, 114, 232]
# docid=65379, tf=2, pos=[24, 91]
# docid=65427, tf=1, pos=[60]
# docid=65506, tf=1, pos=[17]
# docid=65514, tf=1, pos=[86]
# docid=65551, tf=3, pos=[13, 74, 103]
# docid=65609, tf=1, pos=[58]
# docid=65616, tf=4, pos=[134, 137, 192, 197]
# docid=65666, tf=1, pos=[155]
# docid=65723, tf=1, pos=[12]
# docid=65753, tf=1, pos=[10]
# docid=65765, tf=1, pos=[41]
# docid=65821, tf=1, pos=[26]
# docid=65824, tf=2, pos=[88, 344]
# docid=65882, tf=1, pos=[14]
# docid=65978, tf=1, pos=[105]
# docid=66099, tf=2, pos=[66, 152]
# docid=66310, tf=1, pos=[36]
# docid=66508, tf=1, pos=[274]
# docid=66598, tf=3, pos=[9, 54, 226]
# docid=66829, tf=1, pos=[29]
# docid=66869, tf=1, pos=[193]
# docid=67120, tf=9, pos=[5, 76, 93, 128, 155, 187, 247, 257, 276]
# docid=67127, tf=6, pos=[11, 32, 93, 109, 122, 149]
# docid=67131, tf=5, pos=[163, 190, 211, 244, 264]
# docid=67134, tf=3, pos=[16, 69, 187]
# docid=67145, tf=1, pos=[73]
# docid=67180, tf=1, pos=[61]
# docid=67216, tf=1, pos=[40]
# docid=67239, tf=6, pos=[90, 149, 276, 306, 372, 402]
# docid=67240, tf=4, pos=[71, 114, 123, 151]
# docid=67256, tf=2, pos=[94, 104]
# docid=67283, tf=2, pos=[116, 118]
# docid=67309, tf=1, pos=[54]
# docid=67349, tf=1, pos=[84]
# docid=67370, tf=1, pos=[149]
# docid=67388, tf=1, pos=[145]
# docid=67416, tf=1, pos=[147]
# docid=67422, tf=5, pos=[1, 51, 102, 106, 172]
# docid=67431, tf=1, pos=[40]
# docid=67438, tf=1, pos=[21]
# docid=67451, tf=1, pos=[260]
# docid=67472, tf=1, pos=[73]
# docid=67485, tf=1, pos=[210]
# docid=67487, tf=1, pos=[254]
# docid=67511, tf=1, pos=[125]
# docid=67513, tf=1, pos=[64]
# docid=67538, tf=1, pos=[95]
# docid=67592, tf=1, pos=[95]
# docid=67615, tf=1, pos=[38]
# docid=67627, tf=1, pos=[94]
# docid=67645, tf=2, pos=[15, 133]
# docid=67654, tf=1, pos=[39]
# docid=67685, tf=1, pos=[171]
# docid=67703, tf=4, pos=[15, 115, 224, 228]
# docid=67735, tf=5, pos=[3, 90, 98, 120, 134]
# docid=67751, tf=4, pos=[65, 196, 217, 339]
# docid=67753, tf=2, pos=[82, 118]
# docid=67770, tf=1, pos=[33]
# docid=67778, tf=2, pos=[7, 39]
# docid=67782, tf=4, pos=[68, 302, 321, 399]
# docid=67801, tf=1, pos=[54]
# docid=67802, tf=1, pos=[40]
# docid=67811, tf=1, pos=[33]
# docid=67819, tf=1, pos=[132]
# docid=67853, tf=1, pos=[94]
# docid=67874, tf=1, pos=[58]
# docid=67906, tf=2, pos=[164, 322]
# docid=67913, tf=1, pos=[29]
# docid=67932, tf=1, pos=[25]
# docid=67933, tf=12, pos=[30, 126, 137, 153, 181, 197, 209, 219, 253, 287, 303, 317]
# docid=67965, tf=2, pos=[171, 188]
# docid=67979, tf=5, pos=[15, 69, 125, 178, 199]
# docid=68002, tf=1, pos=[29]
# docid=68006, tf=2, pos=[99, 189]
# docid=68009, tf=2, pos=[57, 74]
# docid=68023, tf=1, pos=[151]
# docid=68024, tf=1, pos=[40]
# docid=68026, tf=4, pos=[9, 35, 43, 108]
# docid=68036, tf=2, pos=[32, 59]
# docid=68063, tf=2, pos=[57, 123]
# docid=68066, tf=1, pos=[38]
# docid=68070, tf=5, pos=[7, 43, 66, 95, 153]
# docid=68080, tf=1, pos=[32]
# docid=68087, tf=1, pos=[89]
# docid=68107, tf=1, pos=[91]
# docid=68114, tf=1, pos=[95]
# docid=68130, tf=1, pos=[71]
# docid=68161, tf=2, pos=[87, 155]
# docid=68183, tf=3, pos=[15, 56, 80]
# docid=68202, tf=1, pos=[28]
# docid=68205, tf=1, pos=[154]
# docid=68207, tf=1, pos=[55]
# docid=68247, tf=1, pos=[45]
# docid=68264, tf=1, pos=[160]
# docid=68266, tf=6, pos=[18, 77, 122, 174, 197, 300]
# docid=68269, tf=1, pos=[80]
# docid=68281, tf=1, pos=[21]
# docid=68307, tf=2, pos=[9, 121]
# docid=68309, tf=5, pos=[14, 99, 104, 142, 173]
# docid=68336, tf=1, pos=[30]
# docid=68349, tf=4, pos=[6, 130, 152, 169]
# docid=68350, tf=1, pos=[413]
# docid=68356, tf=3, pos=[73, 168, 222]
# docid=68393, tf=1, pos=[44]
# docid=68400, tf=2, pos=[19, 94]
# docid=68438, tf=3, pos=[216, 232, 270]
# docid=68455, tf=1, pos=[92]
# docid=68460, tf=10, pos=[26, 42, 63, 99, 137, 157, 165, 251, 304, 331]
# docid=68473, tf=1, pos=[89]
# docid=68478, tf=2, pos=[148, 227]
# docid=68484, tf=1, pos=[108]
# docid=68525, tf=1, pos=[287]
# docid=68527, tf=1, pos=[57]
# docid=68563, tf=1, pos=[202]
# docid=68564, tf=1, pos=[248]
# docid=68566, tf=1, pos=[123]
# docid=68583, tf=1, pos=[29]
# docid=68628, tf=1, pos=[53]
# docid=68643, tf=1, pos=[34]
# docid=68654, tf=1, pos=[103]
# docid=68658, tf=1, pos=[180]
# docid=68674, tf=2, pos=[112, 183]
# docid=68676, tf=8, pos=[137, 184, 200, 225, 242, 259, 274, 290]
# docid=68714, tf=1, pos=[138]
# docid=68719, tf=1, pos=[29]
# docid=68776, tf=1, pos=[32]
# docid=68802, tf=1, pos=[193]
# docid=68811, tf=1, pos=[15]
# docid=68817, tf=1, pos=[35]
# docid=68838, tf=10, pos=[13, 60, 88, 150, 158, 180, 201, 226, 241, 266]
# docid=68860, tf=1, pos=[57]
# docid=68866, tf=3, pos=[12, 47, 61]
# docid=68871, tf=3, pos=[72, 113, 133]
# docid=68877, tf=1, pos=[49]
# docid=68893, tf=1, pos=[27]
# docid=68902, tf=1, pos=[89]
# docid=68903, tf=1, pos=[22]
# docid=68910, tf=1, pos=[182]
# docid=68925, tf=1, pos=[175]
# docid=68934, tf=2, pos=[97, 119]
# docid=68972, tf=2, pos=[25, 39]
# docid=68988, tf=1, pos=[76]
# docid=68991, tf=3, pos=[316, 393, 486]
# docid=68993, tf=1, pos=[206]
# docid=69018, tf=1, pos=[23]
# docid=69019, tf=1, pos=[23]
# docid=69046, tf=3, pos=[349, 403, 416]
# docid=69050, tf=1, pos=[117]
# docid=69060, tf=5, pos=[11, 68, 120, 233, 245]
# docid=69137, tf=1, pos=[33]
# docid=69162, tf=1, pos=[40]
# docid=69163, tf=5, pos=[48, 84, 92, 106, 122]
# docid=69174, tf=4, pos=[62, 150, 170, 227]
# docid=69188, tf=4, pos=[22, 53, 79, 87]
# docid=69206, tf=1, pos=[36]
# docid=69230, tf=1, pos=[27]
# docid=69249, tf=1, pos=[15]
# docid=69281, tf=1, pos=[92]
# docid=69316, tf=7, pos=[7, 33, 40, 71, 176, 179, 267]
# docid=69341, tf=1, pos=[24]
# docid=69390, tf=2, pos=[17, 43]
# docid=69409, tf=2, pos=[133, 184]
# docid=69428, tf=2, pos=[19, 274]
# docid=69433, tf=1, pos=[60]
# docid=69461, tf=1, pos=[13]
# docid=69465, tf=1, pos=[164]
# docid=69536, tf=8, pos=[49, 81, 89, 103, 115, 128, 149, 171]
# docid=69575, tf=1, pos=[51]
# docid=69584, tf=1, pos=[102]
# docid=69586, tf=3, pos=[34, 102, 378]
# docid=69605, tf=12, pos=[76, 143, 170, 282, 332, 364, 422, 571, 580, 594, 624, 645]
# docid=69651, tf=2, pos=[18, 71]
# docid=69668, tf=2, pos=[16, 65]
# docid=69725, tf=1, pos=[73]
# docid=69746, tf=2, pos=[50, 72]
# docid=69757, tf=1, pos=[179]
# docid=69785, tf=2, pos=[153, 217]
# docid=69821, tf=1, pos=[138]
# docid=69850, tf=1, pos=[45]
# docid=69891, tf=1, pos=[38]
# docid=69953, tf=1, pos=[76]
# docid=69965, tf=9, pos=[22, 45, 84, 109, 183, 198, 222, 250, 308]
# docid=69968, tf=5, pos=[7, 76, 91, 106, 155]
# docid=69971, tf=1, pos=[37]
# docid=69991, tf=2, pos=[13, 40]
# docid=70008, tf=3, pos=[58, 78, 180]
# docid=70017, tf=1, pos=[148]
# docid=70045, tf=1, pos=[113]
# docid=70054, tf=8, pos=[22, 99, 179, 205, 304, 320, 330, 361]
# docid=70062, tf=10, pos=[5, 70, 75, 114, 197, 230, 250, 260, 332, 363]
# docid=70068, tf=3, pos=[10, 91, 115]
# docid=70105, tf=1, pos=[74]
# docid=70131, tf=2, pos=[194, 328]
# docid=70154, tf=2, pos=[35, 103]
# docid=70175, tf=4, pos=[84, 91, 108, 113]
# docid=70180, tf=1, pos=[124]
# docid=70182, tf=1, pos=[220]
# docid=70197, tf=5, pos=[19, 78, 223, 234, 271]
# docid=70214, tf=1, pos=[50]
# docid=70277, tf=2, pos=[34, 67]
# docid=70291, tf=1, pos=[57]
# docid=70305, tf=1, pos=[17]
# docid=70331, tf=1, pos=[111]
# docid=70337, tf=2, pos=[18, 62]
# docid=70362, tf=6, pos=[31, 87, 103, 127, 148, 179]
# docid=70384, tf=1, pos=[210]
# docid=70403, tf=1, pos=[59]
# docid=70468, tf=3, pos=[82, 282, 393]
# docid=70475, tf=2, pos=[142, 156]
# docid=70481, tf=2, pos=[28, 68]
# docid=70487, tf=1, pos=[23]
# docid=70498, tf=1, pos=[35]
# docid=70505, tf=1, pos=[113]
# docid=70539, tf=1, pos=[39]
# docid=70552, tf=1, pos=[40]
# docid=70590, tf=1, pos=[29]
# docid=70638, tf=1, pos=[44]
# docid=70658, tf=1, pos=[102]
# docid=70736, tf=4, pos=[3, 51, 135, 179]
# docid=70742, tf=1, pos=[261]
# docid=70778, tf=4, pos=[257, 260, 281, 284]
# docid=70817, tf=4, pos=[50, 273, 287, 344]
# docid=70824, tf=1, pos=[90]
# docid=70841, tf=2, pos=[126, 199]
# docid=70859, tf=2, pos=[48, 61]
# docid=70869, tf=1, pos=[80]
# docid=70885, tf=4, pos=[157, 170, 181, 219]
# docid=70886, tf=2, pos=[49, 81]
# docid=70892, tf=3, pos=[97, 156, 165]
# docid=70893, tf=1, pos=[28]
# docid=70912, tf=2, pos=[116, 151]
# docid=70920, tf=1, pos=[133]
# docid=70929, tf=1, pos=[102]
# docid=70932, tf=3, pos=[17, 45, 221]
# docid=70944, tf=1, pos=[20]
# docid=70967, tf=1, pos=[123]
# docid=70969, tf=1, pos=[14]
# docid=71027, tf=2, pos=[100, 167]
# docid=71048, tf=4, pos=[2, 71, 113, 145]
# docid=71053, tf=1, pos=[26]
# docid=71054, tf=1, pos=[73]
# docid=71060, tf=1, pos=[210]
# docid=71081, tf=3, pos=[4, 15, 61]
# docid=71098, tf=7, pos=[124, 162, 174, 200, 252, 268, 290]
# docid=71155, tf=3, pos=[72, 93, 166]
# docid=71156, tf=5, pos=[100, 112, 122, 144, 197]
# docid=71162, tf=4, pos=[27, 112, 210, 345]
# docid=71172, tf=1, pos=[94]
# docid=71186, tf=3, pos=[28, 93, 134]
# docid=71190, tf=1, pos=[137]
# docid=71200, tf=1, pos=[2]
# docid=71205, tf=1, pos=[187]
# docid=71232, tf=4, pos=[145, 168, 186, 212]
# docid=71238, tf=1, pos=[116]
# docid=71291, tf=1, pos=[35]
# docid=71292, tf=1, pos=[76]
# docid=71304, tf=1, pos=[64]
# docid=71307, tf=1, pos=[75]
# docid=71311, tf=1, pos=[169]
# docid=71316, tf=1, pos=[277]
# docid=71333, tf=1, pos=[62]
# docid=71335, tf=1, pos=[102]
# docid=71345, tf=1, pos=[157]
# docid=71358, tf=2, pos=[84, 163]
# docid=71388, tf=2, pos=[21, 255]
# docid=71402, tf=6, pos=[62, 96, 123, 129, 227, 282]
# docid=71404, tf=1, pos=[161]
# docid=71407, tf=18, pos=[4, 33, 44, 101, 111, 124, 145, 154, 165, 171, 198, 202, 228, 251, 255, 267, 280, 297]
# docid=71429, tf=1, pos=[119]
# docid=71445, tf=4, pos=[16, 152, 167, 230]
# docid=71455, tf=1, pos=[69]
# docid=71462, tf=2, pos=[21, 92]
# docid=71464, tf=1, pos=[79]
# docid=71470, tf=1, pos=[246]
# docid=71475, tf=4, pos=[18, 24, 44, 86]
# docid=71491, tf=3, pos=[47, 79, 90]
# docid=71507, tf=1, pos=[50]
# docid=71513, tf=6, pos=[17, 110, 152, 186, 226, 275]
# docid=71540, tf=5, pos=[46, 92, 109, 134, 152]
# docid=71545, tf=1, pos=[99]
# docid=71549, tf=1, pos=[52]
# docid=71577, tf=1, pos=[54]
# docid=71588, tf=2, pos=[14, 44]
# docid=71590, tf=2, pos=[109, 119]
# docid=71594, tf=2, pos=[61, 409]
# docid=71610, tf=4, pos=[53, 84, 117, 153]
# docid=71622, tf=1, pos=[33]
# docid=71655, tf=1, pos=[215]
# docid=71679, tf=1, pos=[223]
# docid=71684, tf=1, pos=[33]
# docid=71706, tf=1, pos=[66]
# docid=71738, tf=1, pos=[11]
# docid=71750, tf=1, pos=[44]
# docid=71780, tf=1, pos=[141]
# docid=71786, tf=1, pos=[88]
# docid=71787, tf=4, pos=[82, 107, 155, 191]
# docid=71846, tf=1, pos=[59]
# docid=71861, tf=4, pos=[10, 68, 81, 152]
# docid=71869, tf=1, pos=[99]
# docid=71884, tf=2, pos=[74, 142]
# docid=71935, tf=1, pos=[107]
# docid=71950, tf=1, pos=[71]
# docid=71963, tf=1, pos=[431]
# docid=71965, tf=1, pos=[41]
# docid=71967, tf=1, pos=[37]
# docid=72009, tf=2, pos=[37, 84]
# docid=72015, tf=1, pos=[29]
# docid=72031, tf=1, pos=[45]
# docid=72035, tf=1, pos=[65]
# docid=72043, tf=2, pos=[21, 49]
# docid=72053, tf=2, pos=[47, 106]
# docid=72055, tf=1, pos=[53]
# docid=72082, tf=1, pos=[31]
# docid=72091, tf=1, pos=[18]
# docid=72107, tf=1, pos=[206]
# docid=72155, tf=1, pos=[105]
# docid=72164, tf=3, pos=[28, 83, 186]
# docid=72174, tf=1, pos=[209]
# docid=72180, tf=1, pos=[147]
# docid=72187, tf=4, pos=[45, 57, 62, 349]
# docid=72228, tf=1, pos=[72]
# docid=72254, tf=1, pos=[31]
# docid=72261, tf=5, pos=[18, 43, 76, 366, 381]
# docid=72267, tf=2, pos=[34, 304]
# docid=72270, tf=2, pos=[271, 323]
# docid=72278, tf=1, pos=[62]
# docid=72281, tf=5, pos=[57, 59, 72, 157, 355]
# docid=72298, tf=1, pos=[70]
# docid=72394, tf=2, pos=[41, 370]
# docid=72396, tf=3, pos=[95, 106, 114]
# docid=72398, tf=1, pos=[62]
# docid=72433, tf=1, pos=[118]
# docid=72463, tf=2, pos=[11, 67]
# docid=72464, tf=2, pos=[10, 62]
# docid=72472, tf=3, pos=[93, 112, 208]
# docid=72485, tf=1, pos=[62]
# docid=72497, tf=1, pos=[76]
# docid=72505, tf=2, pos=[9, 154]
# docid=72515, tf=2, pos=[149, 257]
# docid=72524, tf=1, pos=[151]
# docid=72534, tf=1, pos=[152]
# docid=72542, tf=1, pos=[41]
# docid=72550, tf=5, pos=[14, 17, 27, 51, 67]
# docid=72563, tf=1, pos=[172]
# docid=72565, tf=1, pos=[136]
# docid=72595, tf=1, pos=[20]
# docid=72606, tf=1, pos=[65]
# docid=72654, tf=1, pos=[36]
# docid=72662, tf=2, pos=[67, 76]
# docid=72663, tf=5, pos=[23, 255, 289, 374, 445]
# docid=72700, tf=2, pos=[158, 163]
# docid=72712, tf=3, pos=[70, 100, 223]
# docid=72716, tf=4, pos=[60, 130, 141, 193]
# docid=72719, tf=1, pos=[69]
# docid=72721, tf=2, pos=[61, 73]
# docid=72732, tf=4, pos=[57, 74, 141, 175]
# docid=72745, tf=1, pos=[144]
# docid=72753, tf=1, pos=[433]
# docid=72799, tf=1, pos=[50]
# docid=72801, tf=3, pos=[18, 47, 61]
# docid=72810, tf=1, pos=[59]
# docid=72816, tf=3, pos=[35, 85, 105]
# docid=72849, tf=1, pos=[39]
# docid=72878, tf=1, pos=[227]
# docid=72916, tf=1, pos=[194]
# docid=72932, tf=1, pos=[51]
# docid=72946, tf=1, pos=[43]
# docid=72951, tf=1, pos=[47]
# docid=72982, tf=1, pos=[39]
# docid=73034, tf=3, pos=[132, 151, 179]
# docid=73043, tf=2, pos=[57, 75]
# docid=73101, tf=1, pos=[50]
# docid=73112, tf=2, pos=[94, 346]
# docid=73126, tf=1, pos=[70]
# docid=73132, tf=1, pos=[59]
# docid=73153, tf=1, pos=[76]
# docid=73187, tf=1, pos=[99]
# docid=73194, tf=3, pos=[42, 49, 180]
# docid=73215, tf=1, pos=[38]
# docid=73237, tf=2, pos=[75, 95]
# docid=73245, tf=1, pos=[37]
# docid=73250, tf=3, pos=[18, 73, 103]
# docid=73253, tf=1, pos=[102]
# docid=73260, tf=2, pos=[43, 89]
# docid=73294, tf=1, pos=[190]
# docid=73305, tf=1, pos=[104]
# docid=73328, tf=2, pos=[55, 88]
# docid=73364, tf=3, pos=[175, 177, 185]
# docid=73376, tf=1, pos=[112]
# docid=73388, tf=5, pos=[12, 86, 96, 213, 276]
# docid=73394, tf=1, pos=[171]
# docid=73442, tf=2, pos=[88, 107]
# docid=73473, tf=1, pos=[224]
# docid=73520, tf=1, pos=[29]
# docid=73537, tf=1, pos=[35]
# docid=73555, tf=1, pos=[64]
# docid=73565, tf=2, pos=[35, 139]
# docid=73569, tf=5, pos=[9, 36, 42, 62, 82]
# docid=73585, tf=1, pos=[164]
# docid=73616, tf=4, pos=[29, 44, 111, 158]
# docid=73638, tf=1, pos=[117]
# docid=73652, tf=2, pos=[203, 296]
# docid=73662, tf=1, pos=[50]
# docid=73664, tf=3, pos=[11, 73, 139]
# docid=73679, tf=2, pos=[9, 34]
# docid=73697, tf=1, pos=[84]
# docid=73707, tf=1, pos=[36]
# docid=73711, tf=2, pos=[59, 319]
# docid=73789, tf=4, pos=[121, 123, 170, 193]
# docid=73803, tf=1, pos=[13]
# docid=73818, tf=1, pos=[49]
# docid=73829, tf=1, pos=[51]
# docid=73861, tf=1, pos=[62]
# docid=73865, tf=1, pos=[40]
# docid=73894, tf=3, pos=[118, 132, 222]
# docid=73917, tf=2, pos=[117, 137]
# docid=73967, tf=1, pos=[48]
# docid=73968, tf=1, pos=[93]
# docid=73970, tf=1, pos=[113]
# docid=73986, tf=1, pos=[46]
# docid=74008, tf=1, pos=[50]
# docid=74010, tf=3, pos=[104, 123, 148]
# docid=74024, tf=2, pos=[13, 108]
# docid=74034, tf=1, pos=[15]
# docid=74059, tf=1, pos=[130]
# docid=74072, tf=1, pos=[2]
# docid=74089, tf=2, pos=[140, 260]
# docid=74097, tf=2, pos=[115, 131]
# docid=74107, tf=1, pos=[94]
# docid=74108, tf=5, pos=[16, 114, 145, 190, 259]
# docid=74128, tf=1, pos=[21]
# docid=74132, tf=3, pos=[41, 58, 79]
# docid=74159, tf=7, pos=[12, 108, 125, 183, 207, 222, 242]
# docid=74180, tf=1, pos=[160]
# docid=74187, tf=1, pos=[33]
# docid=74195, tf=1, pos=[88]
# docid=74232, tf=1, pos=[37]
# docid=74250, tf=1, pos=[91]
# docid=74279, tf=2, pos=[162, 241]
# docid=74293, tf=1, pos=[69]
# docid=74295, tf=5, pos=[155, 194, 216, 244, 345]
# docid=74306, tf=1, pos=[42]
# docid=74309, tf=1, pos=[34]
# docid=74367, tf=1, pos=[23]
# docid=74383, tf=1, pos=[17]
# docid=74396, tf=1, pos=[28]
# docid=74422, tf=1, pos=[34]
# docid=74479, tf=2, pos=[76, 123]
# docid=74480, tf=1, pos=[108]
# docid=74504, tf=1, pos=[84]
# docid=74505, tf=1, pos=[276]
# docid=74531, tf=9, pos=[3, 68, 87, 95, 102, 146, 168, 184, 192]
# docid=74545, tf=3, pos=[13, 29, 112]
# docid=74565, tf=1, pos=[111]
# docid=74601, tf=2, pos=[60, 82]
# docid=74653, tf=1, pos=[53]
# docid=74681, tf=4, pos=[10, 68, 82, 261]
# docid=74682, tf=2, pos=[29, 40]
# docid=74692, tf=1, pos=[70]
# docid=74693, tf=1, pos=[183]
# docid=74695, tf=2, pos=[107, 159]
# docid=74716, tf=1, pos=[45]
# docid=74737, tf=8, pos=[37, 88, 244, 254, 263, 287, 297, 349]
# docid=74746, tf=1, pos=[33]
# docid=74750, tf=2, pos=[73, 159]
# docid=74767, tf=3, pos=[13, 18, 116]
# docid=74773, tf=8, pos=[87, 93, 121, 136, 152, 174, 219, 274]
# docid=74776, tf=2, pos=[58, 122]
# docid=74805, tf=1, pos=[39]
# docid=74840, tf=1, pos=[146]
# docid=74856, tf=3, pos=[9, 73, 120]
# docid=74885, tf=1, pos=[30]
# docid=74887, tf=2, pos=[134, 274]
# docid=74913, tf=1, pos=[120]
# docid=74914, tf=2, pos=[10, 203]
# docid=74919, tf=1, pos=[50]
# docid=74922, tf=1, pos=[159]
# docid=74927, tf=1, pos=[386]
# docid=74943, tf=2, pos=[36, 119]
# docid=74958, tf=2, pos=[111, 225]
# docid=74981, tf=2, pos=[104, 184]
# docid=74993, tf=1, pos=[69]
# docid=74995, tf=1, pos=[23]
# docid=74996, tf=1, pos=[180]
# docid=75005, tf=8, pos=[11, 52, 140, 146, 204, 219, 248, 253]
# docid=75011, tf=1, pos=[138]
# docid=75035, tf=2, pos=[47, 112]
# docid=75051, tf=1, pos=[45]
# docid=75074, tf=2, pos=[7, 89]
# docid=75086, tf=1, pos=[324]
# docid=75098, tf=1, pos=[156]
# docid=75114, tf=4, pos=[175, 187, 197, 287]
# docid=75118, tf=1, pos=[64]
# docid=75133, tf=1, pos=[39]
# docid=75153, tf=3, pos=[39, 46, 107]
# docid=75208, tf=3, pos=[13, 97, 142]
# docid=75209, tf=1, pos=[257]
# docid=75240, tf=1, pos=[80]
# docid=75304, tf=1, pos=[63]
# docid=75333, tf=1, pos=[155]
# docid=75377, tf=1, pos=[96]
# docid=75382, tf=1, pos=[107]
# docid=75395, tf=7, pos=[18, 35, 140, 191, 200, 222, 278]
# docid=75398, tf=4, pos=[197, 215, 230, 239]
# docid=75400, tf=1, pos=[97]
# docid=75425, tf=8, pos=[45, 115, 164, 182, 200, 216, 246, 250]
# docid=75430, tf=3, pos=[73, 146, 253]
# docid=75444, tf=1, pos=[32]
# docid=75452, tf=1, pos=[95]
# docid=75467, tf=1, pos=[116]
# docid=75505, tf=1, pos=[220]
# docid=75532, tf=1, pos=[90]
# docid=75594, tf=2, pos=[12, 68]
# docid=75633, tf=2, pos=[85, 132]
# docid=75651, tf=3, pos=[123, 133, 170]
# docid=75657, tf=1, pos=[254]
# docid=75686, tf=1, pos=[62]
# docid=75697, tf=1, pos=[198]
# docid=75715, tf=1, pos=[37]
# docid=75740, tf=1, pos=[15]
# docid=75754, tf=3, pos=[73, 130, 156]
# docid=75760, tf=5, pos=[148, 155, 160, 224, 287]
# docid=75762, tf=9, pos=[9, 127, 129, 146, 203, 228, 243, 279, 315]
# docid=75766, tf=2, pos=[61, 134]
# docid=75770, tf=6, pos=[15, 42, 147, 200, 214, 247]
# docid=75773, tf=1, pos=[183]
# docid=75779, tf=2, pos=[124, 145]
# docid=75787, tf=1, pos=[59]
# docid=75807, tf=1, pos=[304]
# docid=75810, tf=2, pos=[116, 163]
# docid=75829, tf=1, pos=[93]
# docid=75844, tf=1, pos=[60]
# docid=75846, tf=2, pos=[14, 44]
# docid=75859, tf=1, pos=[50]
# docid=75871, tf=1, pos=[34]
# docid=75873, tf=1, pos=[9]
# docid=75893, tf=1, pos=[63]
# docid=75907, tf=1, pos=[82]
# docid=75917, tf=1, pos=[32]
# docid=75925, tf=1, pos=[25]
# docid=75933, tf=1, pos=[39]
# docid=75937, tf=3, pos=[3, 38, 95]
# docid=75939, tf=10, pos=[43, 56, 86, 88, 91, 137, 182, 214, 234, 278]
# docid=75940, tf=9, pos=[8, 40, 55, 72, 76, 89, 141, 145, 169]
# docid=75949, tf=1, pos=[13]
# docid=75961, tf=1, pos=[81]
# docid=75967, tf=1, pos=[34]
# docid=75971, tf=2, pos=[25, 87]
# docid=75979, tf=1, pos=[175]
# docid=75990, tf=1, pos=[14]
# docid=76045, tf=1, pos=[32]
# docid=76147, tf=1, pos=[21]
# docid=76155, tf=1, pos=[176]
# docid=76177, tf=1, pos=[128]
# docid=76191, tf=1, pos=[36]
# docid=76200, tf=2, pos=[98, 104]
# docid=76231, tf=1, pos=[151]
# docid=76255, tf=1, pos=[272]
# docid=76264, tf=1, pos=[77]
# docid=76274, tf=1, pos=[114]
# docid=76306, tf=4, pos=[73, 100, 214, 296]
# docid=76309, tf=1, pos=[39]
# docid=76374, tf=1, pos=[46]
# docid=76376, tf=1, pos=[134]
# docid=76382, tf=3, pos=[41, 69, 91]
# docid=76390, tf=1, pos=[104]
# docid=76394, tf=1, pos=[45]
# docid=76399, tf=1, pos=[90]
# docid=76406, tf=1, pos=[30]
# docid=76414, tf=1, pos=[37]
# docid=76428, tf=2, pos=[72, 78]
# docid=76430, tf=3, pos=[106, 113, 131]
# docid=76568, tf=1, pos=[67]
# docid=76677, tf=1, pos=[51]
# docid=76720, tf=1, pos=[27]
# docid=76752, tf=2, pos=[14, 177]
# docid=76791, tf=2, pos=[12, 134]
# docid=76797, tf=1, pos=[222]
# docid=76822, tf=1, pos=[68]
# docid=76976, tf=1, pos=[16]
# docid=77322, tf=1, pos=[37]
# docid=77431, tf=1, pos=[84]
# docid=77610, tf=2, pos=[54, 91]
# docid=77711, tf=1, pos=[55]
# docid=77882, tf=1, pos=[186]
# docid=77939, tf=2, pos=[5, 113]
# docid=77962, tf=7, pos=[16, 40, 126, 140, 158, 164, 247]
# docid=77989, tf=1, pos=[19]
# docid=78000, tf=1, pos=[131]
# docid=78103, tf=4, pos=[32, 73, 142, 175]
# docid=78118, tf=4, pos=[13, 44, 61, 75]
# docid=78225, tf=1, pos=[96]
# docid=78354, tf=8, pos=[6, 98, 116, 118, 230, 237, 266, 291]
# docid=78526, tf=1, pos=[29]
# docid=78589, tf=1, pos=[104]
# docid=78851, tf=3, pos=[48, 123, 213]
# docid=78900, tf=2, pos=[59, 92]
# docid=78917, tf=1, pos=[215]
# docid=79035, tf=1, pos=[86]
# docid=79333, tf=1, pos=[78]
# docid=79391, tf=1, pos=[23]
# docid=79444, tf=1, pos=[15]
# docid=79468, tf=1, pos=[16]
# docid=79740, tf=1, pos=[73]
# docid=79861, tf=2, pos=[7, 302]
# docid=80012, tf=1, pos=[36]
# docid=80147, tf=1, pos=[39]
# docid=80244, tf=1, pos=[65]
# docid=80415, tf=1, pos=[191]
# docid=80431, tf=1, pos=[47]
# docid=80578, tf=1, pos=[336]
# docid=80672, tf=1, pos=[56]
# docid=80914, tf=2, pos=[9, 103]
# docid=80937, tf=1, pos=[46]
# docid=81024, tf=1, pos=[23]
# docid=81046, tf=1, pos=[20]
# docid=81147, tf=1, pos=[123]
# docid=81279, tf=2, pos=[17, 50]
# docid=81310, tf=1, pos=[23]
# docid=81646, tf=1, pos=[139]
# docid=81717, tf=1, pos=[78]
# docid=81904, tf=6, pos=[17, 110, 152, 186, 226, 275]
# docid=82113, tf=1, pos=[65]
# docid=82180, tf=3, pos=[35, 36, 109]
# docid=82245, tf=1, pos=[323]
# docid=82422, tf=1, pos=[118]
# docid=82526, tf=1, pos=[116]
# docid=82588, tf=2, pos=[3, 65]
# docid=82782, tf=1, pos=[44]
# docid=82963, tf=1, pos=[38]
# docid=82978, tf=3, pos=[14, 67, 224]
# docid=82984, tf=1, pos=[30]
# docid=83041, tf=1, pos=[118]
# docid=83060, tf=1, pos=[177]
# docid=83406, tf=1, pos=[89]
# docid=83409, tf=1, pos=[234]
# docid=83415, tf=2, pos=[31, 47]
# docid=83526, tf=4, pos=[10, 38, 45, 285]
# docid=83541, tf=1, pos=[51]
# docid=83567, tf=7, pos=[14, 53, 81, 96, 129, 170, 237]
# docid=83610, tf=4, pos=[14, 106, 123, 181]
# docid=83747, tf=2, pos=[111, 396]
# docid=83987, tf=1, pos=[207]
# docid=84009, tf=1, pos=[127]
# docid=84082, tf=1, pos=[37]
# docid=84225, tf=1, pos=[244]
# docid=84257, tf=1, pos=[62]
# docid=84359, tf=3, pos=[11, 71, 135]
# docid=84570, tf=1, pos=[207]
# docid=84635, tf=1, pos=[78]
# docid=84650, tf=1, pos=[31]
# docid=84776, tf=1, pos=[43]
# docid=84798, tf=2, pos=[91, 134]
# docid=84869, tf=3, pos=[14, 53, 104]
# docid=84880, tf=1, pos=[119]
# docid=85142, tf=2, pos=[16, 64]
# docid=85302, tf=1, pos=[53]
# docid=85305, tf=1, pos=[27]
# docid=85527, tf=1, pos=[77]
# docid=85645, tf=2, pos=[11, 17]
# docid=85648, tf=1, pos=[59]
# docid=85764, tf=1, pos=[145]
# docid=85878, tf=1, pos=[74]
# docid=86159, tf=1, pos=[81]
# docid=86170, tf=1, pos=[163]
# docid=86203, tf=2, pos=[106, 207]
# docid=86253, tf=1, pos=[70]
# docid=86392, tf=1, pos=[7]
# docid=86549, tf=1, pos=[157]
# docid=86704, tf=2, pos=[10, 54]
# docid=86776, tf=1, pos=[43]
# docid=86873, tf=1, pos=[63]
# docid=87093, tf=1, pos=[151]
# docid=87126, tf=4, pos=[17, 71, 189, 232]
# docid=87157, tf=1, pos=[56]
# docid=87222, tf=2, pos=[17, 41]
# docid=87247, tf=1, pos=[75]
# docid=87487, tf=1, pos=[59]
# docid=87681, tf=1, pos=[56]
# docid=87708, tf=1, pos=[34]
# docid=87793, tf=1, pos=[42]
# docid=87814, tf=3, pos=[14, 46, 81]
# docid=87871, tf=1, pos=[22]
# docid=87913, tf=1, pos=[30]
# docid=87964, tf=3, pos=[13, 35, 69]
# docid=87970, tf=2, pos=[201, 226]
# docid=88030, tf=1, pos=[23]
# docid=88039, tf=3, pos=[7, 25, 54]
# docid=88070, tf=6, pos=[7, 22, 40, 43, 140, 201]
# docid=88191, tf=1, pos=[35]
# docid=88203, tf=1, pos=[170]
# docid=88210, tf=1, pos=[90]
# docid=88222, tf=1, pos=[49]
# docid=88225, tf=1, pos=[7]
# docid=88247, tf=2, pos=[43, 68]
# docid=88255, tf=1, pos=[66]
# docid=88312, tf=1, pos=[29]
# docid=88375, tf=1, pos=[31]
# docid=88384, tf=1, pos=[223]
# docid=88385, tf=1, pos=[231]
# docid=88428, tf=1, pos=[22]
# docid=88453, tf=1, pos=[28]
# docid=88479, tf=1, pos=[158]
# docid=88484, tf=1, pos=[206]
# docid=88616, tf=1, pos=[17]
# docid=88625, tf=1, pos=[23]
# docid=88691, tf=1, pos=[256]
# docid=88771, tf=1, pos=[169]
# docid=88804, tf=2, pos=[13, 76]
# docid=88856, tf=1, pos=[206]
# docid=88861, tf=1, pos=[78]
# docid=88903, tf=1, pos=[17]
# docid=88957, tf=1, pos=[221]
# docid=89020, tf=1, pos=[177]
# docid=89041, tf=1, pos=[122]
# docid=89046, tf=1, pos=[152]
# docid=89052, tf=1, pos=[260]
# docid=89081, tf=4, pos=[36, 98, 125, 183]
# docid=89091, tf=1, pos=[30]
# docid=89115, tf=1, pos=[22]
# docid=89125, tf=1, pos=[53]
# docid=89167, tf=1, pos=[25]
# docid=89186, tf=1, pos=[5]
# docid=89299, tf=3, pos=[12, 52, 73]
# docid=89314, tf=2, pos=[18, 69]
# docid=89336, tf=5, pos=[44, 95, 101, 218, 227]
# docid=89392, tf=1, pos=[71]
# docid=89440, tf=1, pos=[56]
# docid=89455, tf=1, pos=[109]
# docid=89496, tf=1, pos=[37]
# docid=89499, tf=1, pos=[60]
# docid=89511, tf=2, pos=[85, 196]
# docid=89520, tf=1, pos=[183]
# docid=89569, tf=2, pos=[19, 47]
# docid=89594, tf=1, pos=[102]
# docid=89748, tf=1, pos=[45]
# docid=89774, tf=2, pos=[3, 6]
# docid=89782, tf=1, pos=[153]
# docid=89789, tf=1, pos=[51]
# docid=89858, tf=2, pos=[43, 85]
# docid=89865, tf=1, pos=[50]
# docid=89978, tf=1, pos=[33]
# docid=90054, tf=1, pos=[36]
# docid=90264, tf=1, pos=[160]
# docid=90292, tf=1, pos=[374]
# docid=90355, tf=4, pos=[45, 93, 97, 118]
# docid=90359, tf=1, pos=[36]
# docid=90392, tf=2, pos=[12, 19]
# docid=90414, tf=4, pos=[121, 123, 171, 194]
# docid=90431, tf=1, pos=[30]
# docid=90460, tf=1, pos=[66]
# docid=90488, tf=1, pos=[144]
# docid=90524, tf=2, pos=[16, 258]
# docid=90531, tf=3, pos=[61, 69, 151]
# docid=90539, tf=1, pos=[308]
# docid=90563, tf=1, pos=[65]
# docid=90630, tf=1, pos=[145]
# docid=90660, tf=1, pos=[42]
# docid=90689, tf=2, pos=[15, 25]
# docid=90716, tf=3, pos=[29, 48, 55]
# docid=90725, tf=1, pos=[48]
# docid=90733, tf=1, pos=[39]
# docid=90871, tf=3, pos=[53, 114, 147]
# docid=90872, tf=3, pos=[53, 114, 147]
# docid=90880, tf=1, pos=[70]
# docid=90904, tf=1, pos=[65]
# docid=90949, tf=1, pos=[157]
# docid=91006, tf=1, pos=[14]
# docid=91017, tf=1, pos=[75]
# docid=91021, tf=1, pos=[58]
# docid=91070, tf=1, pos=[49]
# docid=91088, tf=1, pos=[50]
# docid=91105, tf=1, pos=[116]
# docid=91118, tf=1, pos=[96]
# docid=91200, tf=3, pos=[147, 196, 235]
# docid=91246, tf=2, pos=[45, 262]
# docid=91259, tf=1, pos=[28]
# docid=91283, tf=1, pos=[171]
# docid=91307, tf=2, pos=[43, 148]
# docid=91313, tf=1, pos=[37]
# docid=91341, tf=1, pos=[188]
# docid=91387, tf=1, pos=[89]
# docid=91427, tf=1, pos=[72]
# docid=91495, tf=2, pos=[16, 80]
# docid=91555, tf=1, pos=[41]
# docid=91565, tf=1, pos=[246]
# docid=91595, tf=1, pos=[36]
# docid=91633, tf=1, pos=[39]
# docid=91640, tf=3, pos=[69, 132, 194]
# docid=91688, tf=1, pos=[72]
# docid=91708, tf=2, pos=[125, 146]
# docid=91723, tf=1, pos=[23]
# docid=91757, tf=1, pos=[17]
# docid=91758, tf=1, pos=[17]
# docid=91788, tf=4, pos=[113, 178, 200, 264]
# docid=91796, tf=1, pos=[37]
# docid=91799, tf=2, pos=[110, 125]
# docid=91817, tf=1, pos=[166]
# docid=91839, tf=1, pos=[36]
# docid=91853, tf=2, pos=[12, 27]
# docid=91858, tf=1, pos=[45]
# docid=91865, tf=1, pos=[78]
# docid=91890, tf=1, pos=[27]
# docid=91947, tf=1, pos=[238]
# docid=91962, tf=1, pos=[31]
# docid=91970, tf=2, pos=[34, 75]
# docid=91986, tf=1, pos=[28]
# docid=91999, tf=1, pos=[35]
# docid=92030, tf=1, pos=[145]
# docid=92057, tf=1, pos=[170]
# docid=92092, tf=1, pos=[94]
# docid=92167, tf=2, pos=[24, 153]
# docid=92200, tf=1, pos=[227]
# docid=92282, tf=5, pos=[4, 102, 156, 257, 294]
# docid=92334, tf=2, pos=[91, 248]
# docid=92348, tf=1, pos=[47]
# docid=92386, tf=1, pos=[35]
# docid=92418, tf=1, pos=[105]
# docid=92497, tf=1, pos=[57]
# docid=92509, tf=1, pos=[29]
# docid=92551, tf=1, pos=[163]
# docid=92575, tf=2, pos=[66, 141]
# docid=92621, tf=1, pos=[412]
# docid=92713, tf=1, pos=[121]
# docid=92716, tf=7, pos=[18, 57, 104, 158, 171, 191, 242]
# docid=92746, tf=1, pos=[76]
# docid=92747, tf=1, pos=[76]
# docid=92776, tf=1, pos=[41]
# docid=92777, tf=1, pos=[80]
# docid=92778, tf=1, pos=[413]
# docid=92783, tf=2, pos=[11, 88]
# docid=92810, tf=1, pos=[138]
# docid=92893, tf=1, pos=[125]
# docid=92894, tf=1, pos=[274]
# docid=92969, tf=1, pos=[64]
# docid=93007, tf=3, pos=[90, 116, 157]
# docid=93149, tf=2, pos=[25, 75]
# docid=93165, tf=1, pos=[58]
# docid=93168, tf=2, pos=[68, 185]
# docid=93265, tf=3, pos=[14, 55, 88]
# docid=93274, tf=1, pos=[55]
# docid=93275, tf=1, pos=[15]
# docid=93287, tf=1, pos=[32]
# docid=93318, tf=2, pos=[93, 139]
# docid=93408, tf=4, pos=[24, 55, 93, 260]
# docid=93477, tf=1, pos=[12]
# docid=93513, tf=1, pos=[70]
# docid=93520, tf=1, pos=[80]
# docid=93538, tf=1, pos=[29]
# docid=93540, tf=1, pos=[58]
# docid=93575, tf=1, pos=[193]
# docid=93665, tf=4, pos=[5, 47, 85, 103]
# docid=93685, tf=1, pos=[227]
# docid=93706, tf=2, pos=[27, 43]
# docid=93742, tf=1, pos=[105]
# docid=93744, tf=3, pos=[143, 170, 210]
# docid=93746, tf=1, pos=[22]
# docid=93747, tf=1, pos=[22]
# docid=93748, tf=2, pos=[72, 121]
# docid=93913, tf=1, pos=[78]
# docid=93941, tf=2, pos=[59, 92]
# docid=93973, tf=1, pos=[11]
# docid=93980, tf=1, pos=[142]
# docid=94001, tf=1, pos=[78]
# docid=94042, tf=2, pos=[15, 126]
# docid=94045, tf=1, pos=[28]
# docid=94088, tf=1, pos=[1]
# docid=94120, tf=1, pos=[55]
# docid=94254, tf=3, pos=[15, 21, 126]
# docid=94283, tf=3, pos=[16, 144, 150]
# docid=94294, tf=1, pos=[20]
# docid=94372, tf=1, pos=[20]
# docid=94373, tf=2, pos=[82, 147]
# docid=94383, tf=1, pos=[40]
# docid=94425, tf=1, pos=[24]
# docid=94459, tf=1, pos=[13]
# docid=94563, tf=1, pos=[136]
# docid=94573, tf=1, pos=[23]
# docid=94606, tf=1, pos=[35]
# docid=94685, tf=2, pos=[19, 66]
# docid=94821, tf=1, pos=[103]
# docid=94870, tf=5, pos=[12, 69, 106, 176, 287]
# docid=94877, tf=1, pos=[34]
# docid=94882, tf=1, pos=[231]
# docid=94889, tf=2, pos=[42, 344]
# docid=94894, tf=3, pos=[104, 209, 259]
# docid=94907, tf=1, pos=[82]
# docid=94909, tf=2, pos=[181, 230]
# docid=95011, tf=1, pos=[117]
# docid=95113, tf=2, pos=[13, 113]
# docid=95243, tf=1, pos=[297]
# docid=95298, tf=1, pos=[15]
# docid=95378, tf=3, pos=[17, 54, 115]
# docid=95611, tf=1, pos=[93]
# docid=95667, tf=1, pos=[16]
# docid=95688, tf=5, pos=[25, 138, 174, 196, 221]
# docid=95734, tf=1, pos=[109]
# docid=95742, tf=1, pos=[48]
# docid=95744, tf=1, pos=[72]
# docid=95750, tf=1, pos=[29]
# docid=95775, tf=1, pos=[189]
# docid=95843, tf=1, pos=[23]
# docid=95863, tf=1, pos=[65]
# docid=95879, tf=1, pos=[11]
# docid=95885, tf=1, pos=[50]
# docid=95934, tf=2, pos=[129, 226]
# docid=96022, tf=1, pos=[38]
# docid=96050, tf=2, pos=[97, 122]
# docid=96061, tf=1, pos=[21]
# docid=96076, tf=1, pos=[134]
# docid=96121, tf=5, pos=[27, 62, 64, 140, 158]
# docid=96129, tf=1, pos=[16]
# ...
# docid=148888, tf=1, pos=[58]
# docid=148917, tf=3, pos=[21, 66, 91]
# docid=148921, tf=2, pos=[19, 55]
# docid=148961, tf=1, pos=[54]
# docid=148979, tf=4, pos=[45, 128, 141, 149]
# docid=149022, tf=4, pos=[93, 95, 163, 190]
# docid=149187, tf=1, pos=[132]
# docid=149276, tf=1, pos=[43]
# docid=149308, tf=1, pos=[20]
# docid=149385, tf=1, pos=[40]
# docid=149393, tf=1, pos=[378]
# docid=149462, tf=1, pos=[30]
# docid=149486, tf=1, pos=[66]
# docid=149510, tf=5, pos=[49, 59, 111, 149, 191]
# docid=149514, tf=1, pos=[84]
# docid=149523, tf=1, pos=[77]
# docid=149551, tf=1, pos=[35]
# docid=149560, tf=1, pos=[106]
# docid=149729, tf=1, pos=[102]
# docid=149731, tf=1, pos=[112]
# docid=149733, tf=1, pos=[202]
# docid=149747, tf=2, pos=[11, 77]
# docid=149927, tf=1, pos=[189]
# docid=149962, tf=1, pos=[288]
# docid=150013, tf=1, pos=[29]
# docid=150072, tf=1, pos=[106]
# docid=150094, tf=1, pos=[135]
# docid=150135, tf=1, pos=[48]
# docid=150173, tf=1, pos=[97]
# docid=150200, tf=2, pos=[45, 262]
# docid=150281, tf=2, pos=[13, 47]
# docid=150292, tf=4, pos=[124, 154, 176, 217]
# docid=150306, tf=1, pos=[36]
# docid=150366, tf=1, pos=[61]
# docid=150373, tf=1, pos=[91]
# docid=150381, tf=1, pos=[29]
# docid=150447, tf=1, pos=[38]
# docid=150549, tf=1, pos=[41]
# docid=150691, tf=1, pos=[51]
# docid=150721, tf=1, pos=[46]
# docid=150834, tf=5, pos=[15, 75, 78, 216, 241]
# docid=150846, tf=1, pos=[18]
# docid=150884, tf=1, pos=[19]
# docid=150995, tf=1, pos=[216]
# docid=150998, tf=1, pos=[42]
# docid=151091, tf=1, pos=[301]
# docid=151097, tf=1, pos=[63]
# docid=151208, tf=1, pos=[129]
# docid=151289, tf=2, pos=[79, 194]
# docid=151353, tf=2, pos=[126, 148]
# docid=151362, tf=1, pos=[76]
# docid=151461, tf=1, pos=[4]
# docid=151473, tf=1, pos=[47]
# docid=151475, tf=1, pos=[82]
# docid=151498, tf=1, pos=[98]
# docid=151618, tf=1, pos=[22]
# docid=151634, tf=6, pos=[19, 25, 43, 66, 139, 172]
# docid=151812, tf=1, pos=[7]
# docid=151822, tf=3, pos=[17, 70, 205]
# docid=151870, tf=1, pos=[29]
# docid=151901, tf=1, pos=[103]
# docid=151904, tf=3, pos=[14, 47, 82]
# docid=151909, tf=4, pos=[9, 12, 113, 141]
# docid=152062, tf=2, pos=[15, 77]
# docid=152113, tf=1, pos=[80]
# docid=152118, tf=2, pos=[18, 40]
# docid=152136, tf=3, pos=[18, 187, 239]
# docid=152166, tf=1, pos=[102]
# docid=152191, tf=1, pos=[103]
# docid=152228, tf=1, pos=[93]
# docid=152259, tf=6, pos=[57, 67, 146, 150, 155, 177]
# docid=152403, tf=1, pos=[120]
# docid=152427, tf=2, pos=[115, 120]
# docid=152522, tf=1, pos=[112]
# docid=152613, tf=1, pos=[473]
# docid=152663, tf=1, pos=[156]
# docid=152695, tf=4, pos=[7, 81, 86, 108]
# docid=152737, tf=1, pos=[56]
# docid=152806, tf=2, pos=[13, 34]
# docid=152882, tf=2, pos=[16, 55]
# docid=152950, tf=1, pos=[63]
# docid=153098, tf=3, pos=[20, 116, 126]
# docid=153110, tf=1, pos=[70]
# docid=153133, tf=1, pos=[204]
# docid=153209, tf=1, pos=[62]
# docid=153219, tf=2, pos=[11, 29]
# docid=153236, tf=6, pos=[10, 20, 80, 157, 184, 244]
# docid=153264, tf=1, pos=[96]
# docid=153272, tf=3, pos=[118, 126, 153]
# docid=153282, tf=3, pos=[72, 273, 385]
# docid=153297, tf=1, pos=[114]
# docid=153332, tf=1, pos=[45]
# docid=153335, tf=2, pos=[112, 273]
# docid=153342, tf=1, pos=[34]
# docid=153349, tf=1, pos=[96]
# docid=153429, tf=1, pos=[70]
# docid=153501, tf=1, pos=[79]
# docid=153548, tf=1, pos=[27]
# docid=153618, tf=1, pos=[84]
# docid=153623, tf=2, pos=[122, 145]
# docid=153764, tf=4, pos=[4, 53, 167, 192]
# docid=153815, tf=1, pos=[135]
# docid=153828, tf=5, pos=[13, 47, 99, 123, 138]
# docid=153835, tf=1, pos=[33]
# docid=153882, tf=2, pos=[17, 87]
# docid=153913, tf=1, pos=[75]
# docid=153916, tf=1, pos=[68]
# docid=153954, tf=1, pos=[190]
# docid=154001, tf=16, pos=[6, 34, 45, 79, 87, 93, 105, 114, 131, 136, 143, 147, 161, 166, 171, 181]
# docid=154049, tf=1, pos=[52]
# docid=154063, tf=1, pos=[32]
# docid=154070, tf=4, pos=[3, 21, 146, 154]
# docid=154074, tf=1, pos=[173]
# docid=154108, tf=1, pos=[76]
# docid=154141, tf=1, pos=[9]
# docid=154149, tf=1, pos=[32]
# docid=154157, tf=1, pos=[30]
# docid=154182, tf=1, pos=[81]
# docid=154218, tf=1, pos=[175]
# docid=154384, tf=1, pos=[33]
# docid=154463, tf=3, pos=[15, 20, 51]
# docid=154467, tf=1, pos=[72]
# docid=154509, tf=4, pos=[9, 19, 123, 141]
# docid=154529, tf=1, pos=[31]
# docid=154538, tf=2, pos=[13, 47]
# docid=154559, tf=1, pos=[11]
# docid=154608, tf=4, pos=[50, 144, 160, 178]
# docid=154640, tf=1, pos=[22]
# docid=154660, tf=3, pos=[140, 147, 162]
# docid=154768, tf=2, pos=[147, 310]
# docid=154851, tf=4, pos=[288, 326, 356, 372]
# docid=154911, tf=1, pos=[146]
# docid=155000, tf=1, pos=[16]
# docid=155017, tf=1, pos=[24]
# docid=155092, tf=1, pos=[187]
# docid=155180, tf=1, pos=[64]
# docid=155181, tf=1, pos=[98]
# docid=155183, tf=1, pos=[28]
# docid=155281, tf=2, pos=[201, 226]
# docid=155325, tf=1, pos=[53]
# docid=155332, tf=1, pos=[24]
# docid=155357, tf=1, pos=[49]
# docid=155360, tf=1, pos=[84]
# docid=155361, tf=2, pos=[24, 108]
# docid=155379, tf=8, pos=[60, 82, 89, 109, 133, 182, 192, 213]
# docid=155544, tf=1, pos=[256]
# docid=155553, tf=1, pos=[137]
# docid=155711, tf=1, pos=[34]
# docid=155752, tf=2, pos=[20, 30]
# docid=155761, tf=2, pos=[11, 45]
# docid=155823, tf=3, pos=[143, 171, 214]
# docid=155891, tf=1, pos=[83]
# docid=156045, tf=1, pos=[108]
# docid=156096, tf=1, pos=[169]
# docid=156100, tf=1, pos=[148]
# docid=156106, tf=1, pos=[72]
# docid=156110, tf=1, pos=[46]
# docid=156119, tf=1, pos=[176]
# docid=156156, tf=1, pos=[38]
# docid=156267, tf=2, pos=[94, 140]
# docid=156295, tf=1, pos=[49]
# docid=156322, tf=2, pos=[112, 270]
# docid=156388, tf=1, pos=[31]
# docid=156449, tf=1, pos=[34]
# docid=156490, tf=1, pos=[92]
# docid=156555, tf=4, pos=[157, 164, 227, 241]
# docid=156558, tf=1, pos=[46]
# docid=156561, tf=1, pos=[142]
# docid=156587, tf=1, pos=[18]
# docid=156647, tf=1, pos=[279]
# docid=156711, tf=1, pos=[7]
# docid=156754, tf=1, pos=[55]
# docid=156828, tf=2, pos=[128, 147]
# docid=156834, tf=1, pos=[39]
# docid=156868, tf=1, pos=[117]
# docid=156914, tf=1, pos=[20]
# docid=156949, tf=1, pos=[19]
# docid=156968, tf=1, pos=[99]
# docid=156988, tf=2, pos=[18, 62]
# docid=157105, tf=1, pos=[8]
# docid=157138, tf=1, pos=[18]
# docid=157214, tf=1, pos=[51]
# docid=157233, tf=1, pos=[100]
# docid=157235, tf=2, pos=[20, 79]
# docid=157407, tf=1, pos=[20]
# docid=157573, tf=1, pos=[33]
# docid=157737, tf=5, pos=[42, 89, 97, 121, 131]
# docid=157884, tf=1, pos=[29]
# docid=157906, tf=1, pos=[219]
# docid=157935, tf=2, pos=[88, 205]
# docid=158026, tf=2, pos=[28, 51]
# docid=158053, tf=1, pos=[31]
# docid=158100, tf=1, pos=[74]
# docid=158147, tf=1, pos=[18]
# docid=158150, tf=1, pos=[142]
# docid=158202, tf=3, pos=[28, 83, 186]
# docid=158272, tf=1, pos=[203]
# docid=158298, tf=1, pos=[30]
# docid=158368, tf=1, pos=[46]
# docid=158381, tf=2, pos=[14, 73]
# docid=158395, tf=1, pos=[22]
# docid=158432, tf=1, pos=[115]
# docid=158442, tf=1, pos=[43]
# docid=158479, tf=1, pos=[179]
# docid=158482, tf=1, pos=[55]
# docid=158512, tf=2, pos=[105, 171]
# docid=158574, tf=1, pos=[74]
# docid=158617, tf=1, pos=[97]
# docid=158805, tf=1, pos=[39]
# docid=158809, tf=1, pos=[43]
# docid=158956, tf=1, pos=[12]
# docid=158966, tf=1, pos=[17]
# docid=158993, tf=1, pos=[179]
# docid=159018, tf=4, pos=[54, 75, 168, 185]
# docid=159033, tf=1, pos=[24]
# docid=159036, tf=2, pos=[14, 29]
# docid=159038, tf=2, pos=[62, 213]
# docid=159058, tf=1, pos=[27]
# docid=159059, tf=1, pos=[108]
# docid=159073, tf=1, pos=[2]
# docid=159148, tf=1, pos=[156]
# docid=159205, tf=1, pos=[77]
# docid=159260, tf=1, pos=[71]
# docid=159346, tf=1, pos=[119]
# docid=159403, tf=1, pos=[207]
# docid=159579, tf=1, pos=[75]
# docid=159623, tf=5, pos=[25, 127, 175, 192, 214]
# docid=159644, tf=1, pos=[59]
# docid=159649, tf=2, pos=[18, 68]
# docid=159667, tf=3, pos=[49, 87, 235]
# docid=159780, tf=1, pos=[245]
# docid=159846, tf=1, pos=[180]
# docid=159860, tf=1, pos=[100]
# docid=159861, tf=1, pos=[124]
# docid=159993, tf=1, pos=[38]
# docid=160029, tf=1, pos=[48]
# docid=160046, tf=1, pos=[66]
# docid=160052, tf=2, pos=[73, 104]
# docid=160057, tf=1, pos=[84]
# docid=160180, tf=1, pos=[45]
# docid=160257, tf=2, pos=[43, 85]
# docid=160355, tf=1, pos=[72]
# docid=160365, tf=2, pos=[146, 226]
# docid=160389, tf=1, pos=[251]
# docid=160429, tf=2, pos=[48, 120]
# docid=160454, tf=1, pos=[48]
# docid=160467, tf=1, pos=[79]
# docid=160578, tf=2, pos=[13, 42]
# docid=160595, tf=2, pos=[234, 264]
# docid=160600, tf=3, pos=[33, 170, 312]
# docid=160630, tf=1, pos=[47]
# docid=160663, tf=1, pos=[35]
# docid=160739, tf=1, pos=[16]
# docid=160750, tf=1, pos=[40]
# docid=160792, tf=1, pos=[56]
# docid=160877, tf=1, pos=[43]
# docid=160906, tf=2, pos=[13, 132]
# docid=160912, tf=1, pos=[93]
# docid=160968, tf=1, pos=[73]
# docid=161056, tf=1, pos=[42]
# docid=161087, tf=6, pos=[34, 57, 79, 114, 142, 173]
# docid=161149, tf=1, pos=[366]
# docid=161167, tf=1, pos=[20]
# docid=161240, tf=1, pos=[15]
# docid=161260, tf=1, pos=[69]
# docid=161356, tf=1, pos=[56]
# docid=161389, tf=2, pos=[234, 260]
# docid=161652, tf=1, pos=[303]
# docid=161800, tf=1, pos=[53]
# docid=161827, tf=1, pos=[107]
# docid=161891, tf=1, pos=[35]
# docid=161895, tf=1, pos=[83]
# docid=161896, tf=1, pos=[174]
# docid=161899, tf=1, pos=[81]
# docid=162092, tf=2, pos=[19, 81]
# docid=162098, tf=1, pos=[13]
# docid=162128, tf=1, pos=[14]
# docid=162184, tf=1, pos=[14]
# docid=162192, tf=1, pos=[84]
# docid=162250, tf=1, pos=[44]
# docid=162252, tf=2, pos=[61, 182]
# docid=162326, tf=1, pos=[145]
# docid=162327, tf=1, pos=[207]
# docid=162347, tf=3, pos=[29, 168, 224]
# docid=162406, tf=1, pos=[139]
# docid=162411, tf=1, pos=[159]
# docid=162498, tf=1, pos=[39]
# docid=162575, tf=1, pos=[43]
# docid=162659, tf=1, pos=[64]
# docid=162668, tf=1, pos=[36]
# docid=162687, tf=1, pos=[73]
# docid=162692, tf=1, pos=[159]
# docid=162715, tf=1, pos=[102]
# docid=162743, tf=1, pos=[24]
# docid=162754, tf=1, pos=[60]
# docid=162793, tf=1, pos=[44]
# docid=162848, tf=1, pos=[60]
# docid=162900, tf=2, pos=[5, 40]
# docid=162906, tf=2, pos=[16, 129]
# docid=162907, tf=1, pos=[91]
# docid=162994, tf=1, pos=[94]
# docid=163011, tf=1, pos=[34]
# docid=163028, tf=1, pos=[33]
# docid=163064, tf=7, pos=[13, 40, 66, 115, 138, 176, 299]
# docid=163071, tf=1, pos=[94]
# docid=163135, tf=1, pos=[31]
# docid=163162, tf=1, pos=[43]
# docid=163179, tf=1, pos=[67]
# docid=163243, tf=1, pos=[17]
# docid=163252, tf=3, pos=[11, 19, 73]
# docid=163282, tf=1, pos=[301]
# docid=163296, tf=1, pos=[146]
# docid=163317, tf=3, pos=[147, 196, 235]
# docid=163438, tf=4, pos=[87, 173, 256, 265]
# docid=163471, tf=6, pos=[95, 122, 153, 159, 184, 201]
# docid=163497, tf=2, pos=[47, 70]
# docid=163507, tf=2, pos=[13, 81]
# docid=163636, tf=1, pos=[93]
# docid=163647, tf=1, pos=[68]
# docid=163752, tf=1, pos=[35]
# docid=163792, tf=1, pos=[70]
# docid=163802, tf=1, pos=[18]
# docid=163823, tf=1, pos=[83]
# docid=163934, tf=2, pos=[15, 128]
# docid=163957, tf=2, pos=[188, 242]
# docid=164054, tf=1, pos=[135]
# docid=164077, tf=8, pos=[14, 59, 82, 112, 156, 167, 186, 192]
# docid=164149, tf=2, pos=[13, 204]
# docid=164252, tf=1, pos=[36]
# docid=164258, tf=6, pos=[31, 147, 158, 186, 203, 264]
# docid=164283, tf=1, pos=[27]
# docid=164323, tf=3, pos=[19, 34, 238]
# docid=164349, tf=1, pos=[106]
# docid=164364, tf=1, pos=[79]
# docid=164367, tf=1, pos=[206]
# docid=164380, tf=1, pos=[106]
# docid=164399, tf=1, pos=[71]
# docid=164407, tf=1, pos=[72]
# docid=164488, tf=1, pos=[168]
# docid=164497, tf=9, pos=[19, 147, 158, 164, 181, 243, 371, 402, 460]
# docid=164515, tf=1, pos=[44]
# docid=164524, tf=1, pos=[93]
# docid=164526, tf=1, pos=[209]
# docid=164543, tf=1, pos=[111]
# docid=164544, tf=1, pos=[24]
# docid=164546, tf=1, pos=[180]
# docid=164564, tf=1, pos=[30]
# docid=164583, tf=1, pos=[29]
# docid=164611, tf=1, pos=[91]
# docid=164637, tf=1, pos=[65]
# docid=164660, tf=1, pos=[45]
# docid=164715, tf=1, pos=[31]
# docid=164755, tf=1, pos=[79]
# docid=164835, tf=1, pos=[95]
# docid=164854, tf=1, pos=[25]
# docid=164891, tf=1, pos=[149]
# docid=164972, tf=2, pos=[15, 38]
# docid=164983, tf=3, pos=[61, 104, 126]
# docid=165055, tf=5, pos=[5, 31, 121, 207, 229]
# docid=165136, tf=1, pos=[56]
# docid=165156, tf=2, pos=[93, 163]
# docid=165247, tf=1, pos=[28]
# docid=165323, tf=1, pos=[128]
# docid=165384, tf=2, pos=[107, 247]
# docid=165397, tf=1, pos=[23]
# docid=165477, tf=2, pos=[20, 138]
# docid=165506, tf=1, pos=[29]
# docid=165519, tf=1, pos=[53]
# docid=165539, tf=1, pos=[35]
# docid=165550, tf=1, pos=[17]
# docid=165568, tf=3, pos=[43, 50, 75]
# docid=165580, tf=4, pos=[9, 18, 48, 186]
# docid=165600, tf=1, pos=[48]
# docid=165603, tf=1, pos=[18]
# docid=165659, tf=2, pos=[11, 72]
# docid=165682, tf=6, pos=[11, 35, 63, 97, 132, 197]
# docid=165739, tf=6, pos=[7, 23, 41, 44, 141, 202]
# docid=165741, tf=2, pos=[65, 148]
# docid=165757, tf=3, pos=[17, 43, 62]
# docid=165839, tf=1, pos=[28]
# docid=165851, tf=1, pos=[106]
# docid=165886, tf=1, pos=[182]
# docid=165891, tf=1, pos=[86]
# docid=165892, tf=1, pos=[53]
# docid=165918, tf=2, pos=[15, 141]
# docid=165936, tf=1, pos=[49]
# docid=166039, tf=1, pos=[50]
# docid=166043, tf=1, pos=[63]
# docid=166115, tf=1, pos=[92]
# docid=166136, tf=1, pos=[171]
# docid=166201, tf=1, pos=[30]
# docid=166212, tf=1, pos=[37]
# docid=166229, tf=1, pos=[59]
# docid=166241, tf=1, pos=[214]
# docid=166398, tf=1, pos=[70]
# docid=166429, tf=1, pos=[64]
# docid=166565, tf=1, pos=[90]
# docid=166605, tf=2, pos=[13, 228]
# docid=166615, tf=7, pos=[2, 22, 42, 55, 82, 115, 121]
# docid=166617, tf=1, pos=[116]
# docid=166640, tf=1, pos=[7]
# docid=166684, tf=5, pos=[8, 138, 164, 216, 227]
# docid=166698, tf=3, pos=[25, 94, 223]
# docid=166741, tf=2, pos=[20, 94]
# docid=166789, tf=2, pos=[33, 224]
# docid=166821, tf=3, pos=[26, 55, 135]
# docid=166956, tf=1, pos=[229]
# docid=167031, tf=1, pos=[123]
# docid=167050, tf=1, pos=[38]
# docid=167096, tf=2, pos=[112, 219]
# docid=167134, tf=2, pos=[12, 57]
# docid=167141, tf=4, pos=[133, 163, 173, 203]
# docid=167151, tf=1, pos=[98]
# docid=167188, tf=1, pos=[19]
# docid=167293, tf=2, pos=[78, 100]
# docid=167489, tf=1, pos=[110]
# docid=167545, tf=3, pos=[173, 410, 432]
# docid=167589, tf=1, pos=[42]
# docid=167594, tf=1, pos=[293]
# docid=167721, tf=1, pos=[112]
# docid=167800, tf=1, pos=[18]
# docid=167801, tf=1, pos=[11]
# docid=167806, tf=1, pos=[217]
# docid=167870, tf=1, pos=[15]
# docid=167886, tf=1, pos=[115]
# docid=167961, tf=3, pos=[18, 105, 451]
# docid=168019, tf=1, pos=[19]
# docid=168046, tf=1, pos=[102]
# docid=168093, tf=2, pos=[122, 240]
# docid=168114, tf=2, pos=[75, 211]
# docid=168134, tf=2, pos=[19, 47]
# docid=168160, tf=1, pos=[211]
# docid=168228, tf=2, pos=[150, 157]
# docid=168316, tf=6, pos=[44, 48, 84, 96, 346, 425]
# docid=168355, tf=1, pos=[24]
# docid=168365, tf=1, pos=[21]
# docid=168434, tf=1, pos=[144]
# docid=168447, tf=1, pos=[28]
# docid=168513, tf=6, pos=[3, 29, 68, 78, 102, 157]
# docid=168546, tf=1, pos=[71]
# docid=168576, tf=1, pos=[35]
# docid=168577, tf=2, pos=[106, 109]
# docid=168585, tf=1, pos=[113]
# docid=168672, tf=2, pos=[14, 68]
# docid=168675, tf=2, pos=[35, 46]
# docid=168679, tf=1, pos=[79]
# docid=168793, tf=2, pos=[35, 144]
# docid=168854, tf=1, pos=[156]
# docid=168859, tf=2, pos=[16, 80]
# docid=168869, tf=5, pos=[25, 138, 174, 196, 221]
# docid=168881, tf=4, pos=[2, 36, 120, 172]
# docid=168892, tf=1, pos=[18]
# docid=168943, tf=1, pos=[82]
# docid=168945, tf=1, pos=[36]
# docid=168985, tf=3, pos=[88, 263, 343]
# docid=169059, tf=1, pos=[66]
# docid=169192, tf=2, pos=[60, 77]
# docid=169293, tf=1, pos=[89]
# docid=169360, tf=4, pos=[9, 20, 91, 153]
# docid=169409, tf=2, pos=[16, 78]
# docid=169514, tf=1, pos=[32]
# docid=169536, tf=2, pos=[117, 213]
# docid=169552, tf=3, pos=[126, 220, 225]
# docid=169670, tf=1, pos=[150]
# docid=169804, tf=1, pos=[81]
# docid=169880, tf=1, pos=[153]
# docid=169985, tf=1, pos=[45]
# docid=170019, tf=1, pos=[70]
# docid=170047, tf=1, pos=[78]
# docid=170111, tf=1, pos=[122]
# docid=170291, tf=1, pos=[55]
# docid=170340, tf=1, pos=[12]
# docid=170388, tf=1, pos=[80]
# docid=170395, tf=3, pos=[18, 147, 157]
# docid=170400, tf=1, pos=[166]
# docid=170461, tf=1, pos=[97]
# docid=170510, tf=2, pos=[66, 141]
# docid=170578, tf=1, pos=[34]
# docid=170625, tf=1, pos=[130]
# docid=170632, tf=1, pos=[123]
# docid=170683, tf=1, pos=[66]
# docid=170686, tf=1, pos=[95]
# docid=170743, tf=1, pos=[44]
# docid=170831, tf=1, pos=[21]
# docid=170832, tf=1, pos=[16]
# docid=170846, tf=1, pos=[55]
# docid=170886, tf=1, pos=[153]
# docid=170910, tf=1, pos=[22]
# docid=170921, tf=1, pos=[158]
# docid=170933, tf=3, pos=[175, 197, 209]
# docid=170937, tf=1, pos=[40]
# docid=171067, tf=1, pos=[66]
# docid=171071, tf=2, pos=[86, 164]
# docid=171163, tf=1, pos=[151]
# docid=171222, tf=1, pos=[26]
# docid=171286, tf=1, pos=[35]
# docid=171300, tf=2, pos=[155, 212]

# %%
# get the sparse doc vector (word, term_freq)
# note that stemming heavily modify the morphology of the word
doc_vector = index_reader.get_document_vector('dv9m19yk')
print(doc_vector)
# Out:
# {'viru': 2, 'been': 1, 'covid': 2, 'virtual': 1, 'fact': 1, 'zoonot': 1, 'origin': 5, 'about': 1, 'cov': 1, 'type': 1, 'dozen': 1, 'everi': 1, 'theori': 1, 'caus': 1, 'hit': 1, 'determin': 1, 'known': 1, 'far': 1, 'have': 1, 'text': 1, 'titl': 1, 'event': 1, 'so': 1, 'all': 1, 'which': 1, 'new': 1, 'like': 1, 'sar': 1, 'occur': 1, 'pandem': 2, 'attribut': 1, '19': 2, 'diseas': 1, 'differ': 1, 'emerg': 1, 'most': 1, '2': 1, 'globe': 1, 'what': 2, 'ha': 2, 'investig': 1, 'except': 1, 'time': 1, 'first': 1}

# %%
print(docid_2_combined_text['dv9m19yk'])
# Out:
# [What is the origin of SARS-CoV-2?] Every time a pandemic occurs, dozens of theories emerge to attribute the origin of the event to different facts. The COVID-19 pandemic that has hit virtually all the globe has been no exception. What is known so far about the origin of the virus that causes COVID 19? The first investigations on the origin of this disease have determined that it is a new type of virus, the origin of which is most likely zoonotic.

# %%
# Note that the keys of get_document_vector() are already analyzed, we set analyzer to be None.
bm25_score = index_reader.compute_bm25_term_weight('dv9m19yk', 'viru', analyzer=None)
print(bm25_score)
# Out:
# 1.191981315612793

# %% [markdown]
# ### Inspect tokenization process
# https://github.com/castorini/pyserini/blob/master/docs/usage-analyzer.md

# %%
from pyserini.analysis import Analyzer, get_lucene_analyzer

# Default analyzer for English uses the Porter stemmer:
# stop words will be removed
analyzer = Analyzer(get_lucene_analyzer())
tokens = analyzer.analyze('City buses are running on time.')
print(tokens)
# Out:
# ['citi', 'buse', 'run', 'time']

# %% [markdown]
# ## Enrich document via generated queries

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch
from huggingface_hub import notebook_login

# Optional: Log in to Hugging Face (if required)
#notebook_login()  #Uncomment if you are in a notebook and need to log in

model_name = 'csdc-atl/doc2query'
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

text = "2014年12月9日，于洋转会至中超联赛球队广州富力。2015赛季初，于洋并没有出场机会。韩国中后卫张贤秀受伤后，主教练选择用金洋洋代替。足协杯4比0战胜贵州人和的比赛中，金洋洋打入两球。赛后，中国足协认定金洋洋在庆祝进球时使用侮辱性手势，将他禁赛四场。之后对阵山东鲁能的联赛，于洋迎来出场机会，首次代表广州富力出战正式比赛。从此开始，于洋得到了较为充足的出场时间。2015赛季于洋中超联赛出场17次、亚冠联赛1次，这18次出场中有17次为首发。2016赛季，于洋成为广州富力三后卫体系的主力，还曾担任队长。这个赛季，他在中超联赛出场25次、足协杯出场5次，联赛的25次出场中含22次首发。效力广州富力期间，他于2015年重返中国国家足球队。\n2016年12月30日，广州富力宣布于洋离队，加盟北京国安。有媒体透露，转会费在5000万至6000万元人民币之间。回归北京国安之后，于洋成为中后卫位置上的主力。2018年3月31日北京国安与北京人和的北京德比上，于洋第100次代表北京国安出场。他在比赛中打入一球，助球队4比0获胜。"


def create_queries(text):
    input_ids = tokenizer.encode(text, return_tensors='pt')
    with torch.no_grad():
        # Here we use top_k / top_k random sampling. It generates more diverse queries, but of lower quality
        sampling_outputs = model.generate(
            input_ids=input_ids,
            max_length=64,
            do_sample=True,
            top_p=0.95,
            top_k=10, 
            num_return_sequences=10
            )
    return [tokenizer.decode(sampling_output, skip_special_tokens=True) for sampling_output in sampling_outputs]


sampling_outputs = create_queries(text)
print("Paragraph:")
print(text)

print("\nSampling Outputs:")
for query in sampling_outputs:
    print(query)
# 1: 于洋在2016年重返中国国家足球队是在哪个球队效力?
# 2: 于洋在2018年3月31日的北京德比上打入了几个球?
# 3: 于洋在哪些比赛中有出场机会?
# 4: 于洋在哪个比赛中打入了两球?
# 5: 于洋在2015赛季中超联赛中出场次数和亚冠联赛中的首发次数分别是多少?
# 6: 于洋在哪个比赛中打入了两球,帮助球队赢了这场比赛?
# 7: 于洋在2018年3月31日北京国安与北京人和的北京德比上打进了几个进球?
# 8: 于洋在2015赛季中超联赛和亚冠联赛中出场次数分别是多少?
# 9: 于洋在广州富力期间曾担任什么职位?
# 10: 于洋在哪些比赛中有出场机会?
# Out:
# Paragraph:
# 2014年12月9日，于洋转会至中超联赛球队广州富力。2015赛季初，于洋并没有出场机会。韩国中后卫张贤秀受伤后，主教练选择用金洋洋代替。足协杯4比0战胜贵州人和的比赛中，金洋洋打入两球。赛后，中国足协认定金洋洋在庆祝进球时使用侮辱性手势，将他禁赛四场。之后对阵山东鲁能的联赛，于洋迎来出场机会，首次代表广州富力出战正式比赛。从此开始，于洋得到了较为充足的出场时间。2015赛季于洋中超联赛出场17次、亚冠联赛1次，这18次出场中有17次为首发。2016赛季，于洋成为广州富力三后卫体系的主力，还曾担任队长。这个赛季，他在中超联赛出场25次、足协杯出场5次，联赛的25次出场中含22次首发。效力广州富力期间，他于2015年重返中国国家足球队。
# 2016年12月30日，广州富力宣布于洋离队，加盟北京国安。有媒体透露，转会费在5000万至6000万元人民币之间。回归北京国安之后，于洋成为中后卫位置上的主力。2018年3月31日北京国安与北京人和的北京德比上，于洋第100次代表北京国安出场。他在比赛中打入一球，助球队4比0获胜。
#
# Sampling Outputs:
# 于洋在哪场比赛中打入了一球,帮助北京国安取得了胜利?
# 于洋为什么在足协杯4比0战胜贵州人和的比赛中被禁赛四场?
# 于洋在哪些比赛中打入了进球?
# 于洋在加盟北京国安之前效力于哪支球队?
# 于洋在2016年的转会费用是多少?
# 于洋在2017年3月31日北京国安的比赛中打进了几个球?
# 于洋在哪些联赛中出场过?
# 于洋在哪些比赛中打入了进球?
# 于洋在2015年重返中国国家足球队时获得了多少的出场时间?
# 于洋在2016赛季中担任过哪些职务?

# %%
from tqdm import tqdm
for i in tqdm(range(len(corpus))):
    text = corpus[i]['full_text']
    generated_queries = create_queries(text)
    concat_query_text = " ".join (generated_queries)
    corpus[i]['queries'] = concat_query_text
# Out:
#   0%|          | 15/171332 [00:41<133:09:31,  2.80s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 4
#       2 for i in tqdm(range(len(corpus))):
#       3     text = corpus[i]['full_text']
# ----> 4     queries = create_queries(text)
#       5     concat_query_text = " ".join (queries)
#       6     corpus[i]['queries'] = concat_query_text
#
# Cell In[3], line 19, in create_queries(para)
#      16 input_ids = tokenizer.encode(para, return_tensors='pt')
#      17 with torch.no_grad():
#      18     # Here we use top_k / top_k random sampling. It generates more diverse queries, but of lower quality
# ---> 19     sampling_outputs = model.generate(
#      20         input_ids=input_ids,
#      21         max_length=64,
#      22         do_sample=True,
#      23         top_p=0.95,
#      24         top_k=10,
#      25         num_return_sequences=10
#      26         )
#      27 return [tokenizer.decode(sampling_output, skip_special_tokens=True) for sampling_output in sampling_outputs]
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/transformers/generation/utils.py:2255, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2247     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2248         input_ids=input_ids,
#    2249         expand_size=generation_config.num_return_sequences,
#    2250         is_encoder_decoder=self.config.is_encoder_decoder,
#    2251         **model_kwargs,
#    2252     )
#    2254     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2255     result = self._sample(
#    2256         input_ids,
#    2257         logits_processor=prepared_logits_processor,
#    2258         stopping_criteria=prepared_stopping_criteria,
#    2259         generation_config=generation_config,
#    2260         synced_gpus=synced_gpus,
#    2261         streamer=streamer,
#    2262         **model_kwargs,
#    2263     )
#    2265 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2266     # 11. prepare beam search scorer
#    2267     beam_scorer = BeamSearchScorer(
#    2268         batch_size=batch_size,
#    2269         num_beams=generation_config.num_beams,
#    (...)
#    2274         max_length=generation_config.max_length,
#    2275     )
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/transformers/generation/utils.py:3257, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3255     is_prefill = False
#    3256 else:
# -> 3257     outputs = model_forward(**model_inputs, return_dict=True)
#    3259 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3260 model_kwargs = self._update_model_kwargs_for_generation(
#    3261     outputs,
#    3262     model_kwargs,
#    3263     is_encoder_decoder=self.config.is_encoder_decoder,
#    3264 )
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/transformers/models/t5/modeling_t5.py:1891, in T5ForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1888         decoder_attention_mask = decoder_attention_mask.to(self.decoder.first_device)
#    1890 # Decode
# -> 1891 decoder_outputs = self.decoder(
#    1892     input_ids=decoder_input_ids,
#    1893     attention_mask=decoder_attention_mask,
#    1894     inputs_embeds=decoder_inputs_embeds,
#    1895     past_key_values=past_key_values,
#    1896     encoder_hidden_states=hidden_states,
#    1897     encoder_attention_mask=attention_mask,
#    1898     head_mask=decoder_head_mask,
#    1899     cross_attn_head_mask=cross_attn_head_mask,
#    1900     use_cache=use_cache,
#    1901     output_attentions=output_attentions,
#    1902     output_hidden_states=output_hidden_states,
#    1903     return_dict=return_dict,
#    1904     cache_position=cache_position,
#    1905 )
#    1907 sequence_output = decoder_outputs[0]
#    1909 # Set device for model parallelism
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/transformers/models/t5/modeling_t5.py:1124, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1107     layer_outputs = self._gradient_checkpointing_func(
#    1108         layer_module.forward,
#    1109         hidden_states,
#    (...)
#    1121         cache_position,
#    1122     )
#    1123 else:
# -> 1124     layer_outputs = layer_module(
#    1125         hidden_states,
#    1126         attention_mask=causal_mask,
#    1127         position_bias=position_bias,
#    1128         encoder_hidden_states=encoder_hidden_states,
#    1129         encoder_attention_mask=encoder_extended_attention_mask,
#    1130         encoder_decoder_position_bias=encoder_decoder_position_bias,
#    1131         layer_head_mask=layer_head_mask,
#    1132         cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1133         past_key_value=past_key_values,
#    1134         use_cache=use_cache,
#    1135         output_attentions=output_attentions,
#    1136         return_dict=return_dict,
#    1137         cache_position=cache_position,
#    1138     )
#    1140 # layer_outputs is a tuple with:
#    1141 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1142 if use_cache is False:
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/transformers/models/t5/modeling_t5.py:699, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict, cache_position)
#     697 do_cross_attention = self.is_decoder and encoder_hidden_states is not None
#     698 if do_cross_attention:
# --> 699     cross_attention_outputs = self.layer[1](
#     700         hidden_states,
#     701         key_value_states=encoder_hidden_states,
#     702         attention_mask=encoder_attention_mask,
#     703         position_bias=encoder_decoder_position_bias,
#     704         layer_head_mask=cross_attn_layer_head_mask,
#     705         past_key_value=past_key_value,
#     706         query_length=cache_position[-1] + 1,
#     707         use_cache=use_cache,
#     708         output_attentions=output_attentions,
#     709     )
#     710     hidden_states, past_key_value = cross_attention_outputs[:2]
#     712     # clamp inf values to enable fp16 training
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/transformers/models/t5/modeling_t5.py:629, in T5LayerCrossAttention.forward(self, hidden_states, key_value_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, query_length, output_attentions, cache_position)
#     615 def forward(
#     616     self,
#     617     hidden_states,
#    (...)
#     626     cache_position=None,
#     627 ):
#     628     normed_hidden_states = self.layer_norm(hidden_states)
# --> 629     attention_output = self.EncDecAttention(
#     630         normed_hidden_states,
#     631         mask=attention_mask,
#     632         key_value_states=key_value_states,
#     633         position_bias=position_bias,
#     634         layer_head_mask=layer_head_mask,
#     635         past_key_value=past_key_value,
#     636         use_cache=use_cache,
#     637         query_length=query_length,
#     638         output_attentions=output_attentions,
#     639         cache_position=cache_position,
#     640     )
#     641     layer_output = hidden_states + self.dropout(attention_output[0])
#     642     outputs = (layer_output,) + attention_output[1:]  # add attentions if we output them
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/huggingface_lastest/lib/python3.11/site-packages/transformers/models/t5/modeling_t5.py:559, in T5Attention.forward(self, hidden_states, mask, key_value_states, position_bias, past_key_value, layer_head_mask, query_length, use_cache, output_attentions, cache_position)
#     556 if layer_head_mask is not None:
#     557     attn_weights = attn_weights * layer_head_mask
# --> 559 attn_output = torch.matmul(attn_weights, value_states)
#     561 attn_output = attn_output.transpose(1, 2).contiguous()
#     562 attn_output = attn_output.view(batch_size, -1, self.inner_dim)
#
# KeyboardInterrupt:
